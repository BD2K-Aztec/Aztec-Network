# %% [markdown]
# ### Network-Data

# %% [markdown]
# Data Preparation

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from time import time

# %%
% matplotlib inline
import json

# %% [markdown]
# ### Get all data

# %%
import glob
ann_files =  glob.glob("../data/*.ann")
len(ann_files)
# Out:
# 200

# %% [markdown]
# #### Get T and E and R data :

# %%
"""============================================================
This class helps to read data from 'sample.ann' files to create
nodes and edges for network and graph analysis

By: Sigdel D.       Data-2018-Jan-10
==============================================================="""



class DataReader(object):
    
    """Llist: list of lines of files
       t_dict :  dictionary of T-terms
       e_dict : dictionary of e-terms
       r_dict : dictionary of r-terms
       Nodes: List of nodes
       Edges : List of edges"""
    
    
    def __init__(self,input_file):
        #Input file shoulsd be provided
        self.input_file = input_file
        self.Llist = []
        self.t_dict = {}  
        self.e_dict = {}
        self.r_dict = {}
        self.node_dict ={}
        self.Nodes  =[]
        self.Edges = []
        
        
        self.group = ['Coreference', 'Severity', 'Occupation', 'Other_event',\
                      'Frequency', 'Gender', 'Biological_structure', 'Volume',\
                      'Biological_attribute', 'Age', 'Sign_symptom', 'Date',\
                      'History', 'Time', 'Shape', 'Lab_value', 'Nonbiological_location',\
                      'Administration', 'Distance', 'Other_entity', 'Height',\
                      'Activity', 'Family_history', 'Dosage', 'Ethnicity',\
                      'Subject', 'Detailed_description', 'Qualitative_concept',\
                      'Texture', 'Area', 'Weight', 'Quantitative_concept', \
                      'Therapeutic_procedure', 'Disease_disorder', 'Duration',\
                      'Color', 'Medication', 'Diagnostic_procedure']
        
        
        self.relations = ['BEFORE','MODIFY','SUB_PROCEDURE','IDENTICAL','AFTER'\
                        'OVERLAP', 'CAUSE','CO-OCCURANCE','DECREASE_TO',\
                        'DECREASE_FROM', 'INCREASE_FROM','INCREASE_TO']
        
        
        
        
    # function to sum charcters in the list    
    def sum_chr_items(self, items):
        st =""
        for item in items:
            st = st+" "+item
        return st
    
    
    
    # Line of text is converted to list
    def line_to_list(self):
        with open(self.input_file) as f:
            for line in f:
                self.Llist.append(line.split())
                
                
                
                
    def find_group(self,g):
        for k,item in enumerate(self.group):
            if item == g:
                return(k+1)
            
            
                
    def find_edg_value(self,eg):
        for k,item in enumerate(self.relations):
            if item == eg:
                return(2+(k+1))
            
            
    def set_tdata(self):
        for item in self.Llist:
            if item[0][0] =="T":
                t_key = item[0]
                t_type = item[1]
                t_val = self.sum_chr_items(item[4:])
                
                self.t_dict.update({t_key:[t_type,t_val]})
                
                self.node_dict.update({t_key:[t_type,t_val]})
                
                self.Nodes.append({"id":t_key,\
                              "type":t_type,\
                              "group":self.find_group(t_type),\
                              "name":t_val})
               
                    
                
                
                
    def set_edata(self):
        for item in self.Llist:            
            if item[0][0] =="E":
                t_key = item[1].split(':')[1]
                e_key = item[0]
                e_type = item[1].split(':')[0]
                e_val = self.t_dict[t_key][1]
                
                
                self.e_dict.update({e_key:[e_type,e_val]})
                
                self.node_dict.update({e_key:[e_type,e_val]})  
                
                self.Nodes.append({"id":e_key,\
                            "type":e_type,\
                            "group":self.find_group(e_type),\
                            "name":e_val})
                
                
                
    def set_rdata(self):
        for item in self.Llist:           
            if item[0][0] =="R":
                r_key = item[0]
                rln = item[1]
                fm_id = item[2].split(":")[1]
                to_id = item[3].split(":")[1]
                fm_type = self.node_dict[fm_id][0]
                to_type = self.node_dict[to_id][0]
                fm_name = self.node_dict[fm_id][1]
                to_name = self.node_dict[to_id][1]
                
                self.r_dict.update({r_key:[rln,fm_id,to_id]}) 

                self.Edges.append({"id":r_key,\
                            "name":rln,\
                            "value":self.find_edg_value(rln),\
                            "source":fm_id,\
                            "source_name":fm_name,\
                            "source_group":self.find_group(fm_type),\
                            "target":to_id,\
                            "target_name":to_name,\
                            "target_group":self.find_group(to_type)})
                
    
                
    def data_dumper(self,file_name,data):
            with open(file_name, 'w') as fp:
                json.dump(data, fp)
                
    
     
    def get_nodes(self,dump=False):
        self.line_to_list()
        self.set_tdata()
        self.set_edata()
        if dump:
            self.data_dumper(file_name = 'nodes.json',data = self.Nodes)
        return self.Nodes
    
    
    
    def get_edges(self, dump=False):
        self.set_rdata()
        if dump:
            self.data_dumper(file_name = 'edges.json',data = self.Edges)
        return self.Edges
    
    
    def get_data(self,dump=False):
        all_data = {}
        nodes = self.get_nodes()
        edges = self.get_edges()
        
        all_data.update({'nodes':nodes,'links':edges })
        
        
        
        if dump:
            self.data_dumper(file_name = 'data.json',data = all_data) 
        
        return all_data

# %%
DR = DataReader(ann_files[2])

# %%
DR.get_data(dump=True)
# Out:
# {'links': [{'id': 'R1',
#    'name': 'MODIFY',
#    'source': 'T10',
#    'source_group': 7,
#    'source_name': ' abdominal',
#    'target': 'E5',
#    'target_group': 11,
#    'target_name': ' pain',
#    'value': 4},
#   {'id': 'R2',
#    'name': 'MODIFY',
#    'source': 'T12',
#    'source_group': 7,
#    'source_name': ' stomal',
#    'target': 'E7',
#    'target_group': 11,
#    'target_name': ' diarrhoea',
#    'value': 4},
#   {'id': 'R3',
#    'name': 'MODIFY',
#    'source': 'E2',
#    'source_group': 35,
#    'source_name': ' 4 year',
#    'target': 'E1',
#    'target_group': 34,
#    'target_name': " Crohn's disease",
#    'value': 4},
#   {'id': 'R4',
#    'name': 'MODIFY',
#    'source': 'E8',
#    'source_group': 35,
#    'source_name': ' two day',
#    'target': 'E3',
#    'target_group': 11,
#    'target_name': ' malaise',
#    'value': 4},
#   {'id': 'R5',
#    'name': 'MODIFY',
#    'source': 'E8',
#    'source_group': 35,
#    'source_name': ' two day',
#    'target': 'E4',
#    'target_group': 11,
#    'target_name': ' fever',
#    'value': 4},
#   {'id': 'R6',
#    'name': 'MODIFY',
#    'source': 'E8',
#    'source_group': 35,
#    'source_name': ' two day',
#    'target': 'E5',
#    'target_group': 11,
#    'target_name': ' pain',
#    'value': 4},
#   {'id': 'R7',
#    'name': 'MODIFY',
#    'source': 'E8',
#    'source_group': 35,
#    'source_name': ' two day',
#    'target': 'E6',
#    'target_group': 11,
#    'target_name': ' vomiting',
#    'value': 4},
#   {'id': 'R8',
#    'name': 'MODIFY',
#    'source': 'E8',
#    'source_group': 35,
#    'source_name': ' two day',
#    'target': 'E7',
#    'target_group': 11,
#    'target_name': ' diarrhoea',
#    'value': 4},
#   {'id': 'R9',
#    'name': 'MODIFY',
#    'source': 'T16',
#    'source_group': 7,
#    'source_name': ' joint',
#    'target': 'E9',
#    'target_group': 11,
#    'target_name': ' pains',
#    'value': 4},
#   {'id': 'R10',
#    'name': 'MODIFY',
#    'source': 'T17',
#    'source_group': 7,
#    'source_name': ' shoulders',
#    'target': 'E9',
#    'target_group': 11,
#    'target_name': ' pains',
#    'value': 4},
#   {'id': 'R11',
#    'name': 'MODIFY',
#    'source': 'T18',
#    'source_group': 7,
#    'source_name': ' elbows',
#    'target': 'E9',
#    'target_group': 11,
#    'target_name': ' pains',
#    'value': 4},
#   {'id': 'R12',
#    'name': 'MODIFY',
#    'source': 'T19',
#    'source_group': 7,
#    'source_name': ' wrists',
#    'target': 'E9',
#    'target_group': 11,
#    'target_name': ' pains',
#    'value': 4},
#   {'id': 'R13',
#    'name': 'MODIFY',
#    'source': 'T20',
#    'source_group': 7,
#    'source_name': ' metacarpophalangeals',
#    'target': 'E9',
#    'target_group': 11,
#    'target_name': ' pains',
#    'value': 4},
#   {'id': 'R14',
#    'name': 'MODIFY',
#    'source': 'T21',
#    'source_group': 7,
#    'source_name': ' knees',
#    'target': 'E9',
#    'target_group': 11,
#    'target_name': ' pains',
#    'value': 4},
#   {'id': 'R15',
#    'name': 'MODIFY',
#    'source': 'T22',
#    'source_group': 7,
#    'source_name': ' ankles',
#    'target': 'E9',
#    'target_group': 11,
#    'target_name': ' pains',
#    'value': 4},
#   {'id': 'R16',
#    'name': 'MODIFY',
#    'source': 'T24',
#    'source_group': 7,
#    'source_name': ' elbows',
#    'target': 'E10',
#    'target_group': 11,
#    'target_name': ' rash',
#    'value': 4},
#   {'id': 'R17',
#    'name': 'MODIFY',
#    'source': 'T25',
#    'source_group': 7,
#    'source_name': ' ankles',
#    'target': 'E10',
#    'target_group': 11,
#    'target_name': ' rash',
#    'value': 4},
#   {'id': 'R18',
#    'name': 'MODIFY',
#    'source': 'T26',
#    'source_group': 7,
#    'source_name': ' feet',
#    'target': 'E10',
#    'target_group': 11,
#    'target_name': ' rash',
#    'value': 4},
#   {'id': 'R19',
#    'name': 'MODIFY',
#    'source': 'T28',
#    'source_group': 27,
#    'source_name': ' erythematous',
#    'target': 'E11',
#    'target_group': 11,
#    'target_name': ' macules',
#    'value': 4},
#   {'id': 'R20',
#    'name': 'MODIFY',
#    'source': 'T31',
#    'source_group': 27,
#    'source_name': ' vesico-pustular',
#    'target': 'E12',
#    'target_group': 11,
#    'target_name': ' lesions',
#    'value': 4},
#   {'id': 'R21',
#    'name': 'MODIFY',
#    'source': 'T40',
#    'source_group': 27,
#    'source_name': ' ileo-cutaneous',
#    'target': 'E20',
#    'target_group': 11,
#    'target_name': ' fistula',
#    'value': 4},
#   {'id': 'R22',
#    'name': 'MODIFY',
#    'source': 'T41',
#    'source_group': 27,
#    'source_name': ' complex',
#    'target': 'E20',
#    'target_group': 11,
#    'target_name': ' fistula',
#    'value': 4},
#   {'id': 'R23',
#    'name': 'MODIFY',
#    'source': 'T42',
#    'source_group': 27,
#    'source_name': ' blind tracts',
#    'target': 'E20',
#    'target_group': 11,
#    'target_name': ' fistula',
#    'value': 4},
#   {'id': 'R24',
#    'name': 'MODIFY',
#    'source': 'T45',
#    'source_group': 27,
#    'source_name': ' defunctioning',
#    'target': 'E22',
#    'target_group': 33,
#    'target_name': ' ileostomy',
#    'value': 4},
#   {'id': 'R25',
#    'name': 'MODIFY',
#    'source': 'T47',
#    'source_group': 7,
#    'source_name': ' abdominal',
#    'target': 'E23',
#    'target_group': 11,
#    'target_name': ' pain',
#    'value': 4},
#   {'id': 'R26',
#    'name': 'MODIFY',
#    'source': 'T48',
#    'source_group': 27,
#    'source_name': ' persistent',
#    'target': 'E23',
#    'target_group': 11,
#    'target_name': ' pain',
#    'value': 4},
#   {'id': 'R28',
#    'name': 'MODIFY',
#    'source': 'T55',
#    'source_group': 7,
#    'source_name': ' ileal',
#    'target': 'E27',
#    'target_group': 11,
#    'target_name': ' stricture',
#    'value': 4},
#   {'id': 'R29',
#    'name': 'MODIFY',
#    'source': 'T56',
#    'source_group': 27,
#    'source_name': ' terminal',
#    'target': 'E27',
#    'target_group': 11,
#    'target_name': ' stricture',
#    'value': 4},
#   {'id': 'R30',
#    'name': 'MODIFY',
#    'source': 'T57',
#    'source_group': 7,
#    'source_name': ' ileo-rectal',
#    'target': 'E26',
#    'target_group': 11,
#    'target_name': ' fistula',
#    'value': 4},
#   {'id': 'R31',
#    'name': 'IDENTICAL',
#    'source': 'E28',
#    'source_group': 1,
#    'source_name': ' bowel disease',
#    'target': 'E1',
#    'target_group': 34,
#    'target_name': " Crohn's disease",
#    'value': 6},
#   {'id': 'R32',
#    'name': 'MODIFY',
#    'source': 'T63',
#    'source_group': 24,
#    'source_name': ' three infusions',
#    'target': 'E31',
#    'target_group': 37,
#    'target_name': ' Infliximab',
#    'value': 4},
#   {'id': 'R33',
#    'name': 'MODIFY',
#    'source': 'T70',
#    'source_group': 27,
#    'source_name': ' resting',
#    'target': 'E37',
#    'target_group': 11,
#    'target_name': ' tachycardia',
#    'value': 4},
#   {'id': 'R34',
#    'name': 'MODIFY',
#    'source': 'T71',
#    'source_group': 16,
#    'source_name': ' 125/minute',
#    'target': 'E37',
#    'target_group': 11,
#    'target_name': ' tachycardia',
#    'value': 4},
#   {'id': 'R35',
#    'name': 'MODIFY',
#    'source': 'T76',
#    'source_group': 2,
#    'source_name': ' minimally',
#    'target': 'E40',
#    'target_group': 11,
#    'target_name': ' tender',
#    'value': 4},
#   {'id': 'R36',
#    'name': 'MODIFY',
#    'source': 'T77',
#    'source_group': 7,
#    'source_name': ' ileostomy',
#    'target': 'E40',
#    'target_group': 11,
#    'target_name': ' tender',
#    'value': 4},
#   {'id': 'R39',
#    'name': 'MODIFY',
#    'source': 'T90',
#    'source_group': 7,
#    'source_name': ' metacarpophalangeal',
#    'target': 'T91',
#    'target_group': 7,
#    'target_name': ' joints',
#    'value': 4},
#   {'id': 'R40',
#    'name': 'MODIFY',
#    'source': 'T89',
#    'source_group': 7,
#    'source_name': ' proximal interphalangeal',
#    'target': 'T91',
#    'target_group': 7,
#    'target_name': ' joints',
#    'value': 4},
#   {'id': 'R41',
#    'name': 'MODIFY',
#    'source': 'T87',
#    'source_group': 7,
#    'source_name': ' wrists',
#    'target': 'E46',
#    'target_group': 11,
#    'target_name': ' synovitis',
#    'value': 4},
#   {'id': 'R42',
#    'name': 'MODIFY',
#    'source': 'T91',
#    'source_group': 7,
#    'source_name': ' joints',
#    'target': 'E46',
#    'target_group': 11,
#    'target_name': ' synovitis',
#    'value': 4},
#   {'id': 'R43',
#    'name': 'MODIFY',
#    'source': 'T92',
#    'source_group': 7,
#    'source_name': ' both ankles',
#    'target': 'E46',
#    'target_group': 11,
#    'target_name': ' synovitis',
#    'value': 4},
#   {'id': 'R44',
#    'name': 'MODIFY',
#    'source': 'T103',
#    'source_group': 16,
#    'source_name': ' 69 mm/hr',
#    'target': 'E53',
#    'target_group': 38,
#    'target_name': ' erythrocyte sedimentation rate',
#    'value': 4},
#   {'id': 'R45',
#    'name': 'MODIFY',
#    'source': 'T102',
#    'source_group': 16,
#    'source_name': ' 37.7 mg/L',
#    'target': 'E52',
#    'target_group': 38,
#    'target_name': ' C- reactive protein',
#    'value': 4},
#   {'id': 'R46',
#    'name': 'MODIFY',
#    'source': 'T101',
#    'source_group': 16,
#    'source_name': ' 585 × 109/L',
#    'target': 'E51',
#    'target_group': 38,
#    'target_name': ' platelets',
#    'value': 4},
#   {'id': 'R47',
#    'name': 'MODIFY',
#    'source': 'T100',
#    'source_group': 16,
#    'source_name': ' 15.8 × 109/L',
#    'target': 'E50',
#    'target_group': 38,
#    'target_name': ' white blood count',
#    'value': 4},
#   {'id': 'R48',
#    'name': 'MODIFY',
#    'source': 'T99',
#    'source_group': 16,
#    'source_name': ' 13.1 gm/dl',
#    'target': 'E49',
#    'target_group': 38,
#    'target_name': ' haemoglobin',
#    'value': 4},
#   {'id': 'R49',
#    'name': 'SUB_PROCEDURE',
#    'source': 'E49',
#    'source_group': 38,
#    'source_name': ' haemoglobin',
#    'target': 'E48',
#    'target_group': 38,
#    'target_name': ' laboratory tests',
#    'value': 5},
#   {'id': 'R50',
#    'name': 'SUB_PROCEDURE',
#    'source': 'E50',
#    'source_group': 38,
#    'source_name': ' white blood count',
#    'target': 'E48',
#    'target_group': 38,
#    'target_name': ' laboratory tests',
#    'value': 5},
#   {'id': 'R51',
#    'name': 'SUB_PROCEDURE',
#    'source': 'E51',
#    'source_group': 38,
#    'source_name': ' platelets',
#    'target': 'E48',
#    'target_group': 38,
#    'target_name': ' laboratory tests',
#    'value': 5},
#   {'id': 'R52',
#    'name': 'SUB_PROCEDURE',
#    'source': 'E52',
#    'source_group': 38,
#    'source_name': ' C- reactive protein',
#    'target': 'E48',
#    'target_group': 38,
#    'target_name': ' laboratory tests',
#    'value': 5},
#   {'id': 'R53',
#    'name': 'SUB_PROCEDURE',
#    'source': 'E53',
#    'source_group': 38,
#    'source_name': ' erythrocyte sedimentation rate',
#    'target': 'E48',
#    'target_group': 38,
#    'target_name': ' laboratory tests',
#    'value': 5},
#   {'id': 'R54',
#    'name': 'MODIFY',
#    'source': 'T114',
#    'source_group': 7,
#    'source_name': ' Transthoracic',
#    'target': 'E62',
#    'target_group': 38,
#    'target_name': ' echocardiogram',
#    'value': 4},
#   {'id': 'R55',
#    'name': 'MODIFY',
#    'source': 'T117',
#    'source_group': 28,
#    'source_name': ' sterile',
#    'target': 'E64',
#    'target_group': 38,
#    'target_name': ' multiple blood cultures',
#    'value': 4},
#   {'id': 'R56',
#    'name': 'MODIFY',
#    'source': 'T119',
#    'source_group': 7,
#    'source_name': ' skin',
#    'target': 'E65',
#    'target_group': 38,
#    'target_name': ' biopsy',
#    'value': 4},
#   {'id': 'R57',
#    'name': 'MODIFY',
#    'source': 'T123',
#    'source_group': 27,
#    'source_name': ' leukocytoclastic',
#    'target': 'E66',
#    'target_group': 34,
#    'target_name': ' vasculitis',
#    'value': 4},
#   {'id': 'R58',
#    'name': 'MODIFY',
#    'source': 'T121',
#    'source_group': 7,
#    'source_name': ' lymphohistiocytic',
#    'target': 'T124',
#    'target_group': 7,
#    'target_name': ' infiltrate',
#    'value': 4},
#   {'id': 'R59',
#    'name': 'MODIFY',
#    'source': 'T120',
#    'source_group': 7,
#    'source_name': ' perivascular',
#    'target': 'T124',
#    'target_group': 7,
#    'target_name': ' infiltrate',
#    'value': 4},
#   {'id': 'R60',
#    'name': 'MODIFY',
#    'source': 'T127',
#    'source_group': 27,
#    'source_name': ' fibrinoid',
#    'target': 'E67',
#    'target_group': 11,
#    'target_name': ' necrosis',
#    'value': 4},
#   {'id': 'R61',
#    'name': 'MODIFY',
#    'source': 'T128',
#    'source_group': 7,
#    'source_name': ' vessels',
#    'target': 'E67',
#    'target_group': 11,
#    'target_name': ' necrosis',
#    'value': 4},
#   {'id': 'R62',
#    'name': 'MODIFY',
#    'source': 'T130',
#    'source_group': 24,
#    'source_name': ' 60 mg',
#    'target': 'E68',
#    'target_group': 37,
#    'target_name': ' prednisolone',
#    'value': 4},
#   {'id': 'R63',
#    'name': 'MODIFY',
#    'source': 'T131',
#    'source_group': 24,
#    'source_name': ' per day',
#    'target': 'E68',
#    'target_group': 37,
#    'target_name': ' prednisolone',
#    'value': 4},
#   {'id': 'R64',
#    'name': 'MODIFY',
#    'source': 'T134',
#    'source_group': 27,
#    'source_name': ' prompt',
#    'target': 'E69',
#    'target_group': 11,
#    'target_name': ' resolution of all features',
#    'value': 4},
#   {'id': 'R65',
#    'name': 'MODIFY',
#    'source': 'T133',
#    'source_group': 27,
#    'source_name': ' complete',
#    'target': 'E69',
#    'target_group': 11,
#    'target_name': ' resolution of all features',
#    'value': 4},
#   {'id': 'R66',
#    'name': 'CAUSE',
#    'source': 'E68',
#    'source_group': 37,
#    'source_name': ' prednisolone',
#    'target': 'E69',
#    'target_group': 11,
#    'target_name': ' resolution of all features',
#    'value': 8},
#   {'id': 'R67',
#    'name': 'MODIFY',
#    'source': 'E74',
#    'source_group': 22,
#    'source_name': ' tapered',
#    'target': 'E70',
#    'target_group': 37,
#    'target_name': ' prednisolone',
#    'value': 4},
#   {'id': 'R68',
#    'name': 'MODIFY',
#    'source': 'E73',
#    'source_group': 35,
#    'source_name': ' over the course of one month',
#    'target': 'E74',
#    'target_group': 22,
#    'target_name': ' tapered',
#    'value': 4},
#   {'id': 'R69',
#    'name': 'MODIFY',
#    'source': 'T140',
#    'source_group': 27,
#    'source_name': ' antineutrophil',
#    'target': 'E61',
#    'target_group': 38,
#    'target_name': ' cytoplasmic antibodies',
#    'value': 4},
#   {'id': 'R70',
#    'name': 'MODIFY',
#    'source': 'T141',
#    'source_group': 27,
#    'source_name': ' antinuclear',
#    'target': 'E61',
#    'target_group': 38,
#    'target_name': ' cytoplasmic antibodies',
#    'value': 4},
#   {'id': 'R71',
#    'name': 'BEFORE',
#    'source': 'E1',
#    'source_group': 34,
#    'source_name': " Crohn's disease",
#    'target': 'E77',
#    'target_group': 22,
#    'target_name': ' presented',
#    'value': 3},
#   {'id': 'R72',
#    'name': 'BEFORE',
#    'source': 'E17',
#    'source_group': 12,
#    'source_name': ' 4 months earlier',
#    'target': 'E18',
#    'target_group': 12,
#    'target_name': ' One month earlier',
#    'value': 3},
#   {'id': 'R73',
#    'name': 'AFTER',
#    'source': 'E15',
#    'source_group': 37,
#    'source_name': ' no regular medication',
#    'target': 'E16',
#    'target_group': 37,
#    'target_name': ' Pentasa',
#    'value': None},
#   {'id': 'R74',
#    'name': 'BEFORE',
#    'source': 'E20',
#    'source_group': 11,
#    'source_name': ' fistula',
#    'target': 'E21',
#    'target_group': 12,
#    'target_name': ' two weeks earlier',
#    'value': 3},
#   {'id': 'R27',
#    'name': 'MODIFY',
#    'source': 'T50',
#    'source_group': 7,
#    'source_name': ' cutaneous',
#    'target': 'E78',
#    'target_group': 11,
#    'target_name': ' fistula',
#    'value': 4},
#   {'id': 'R75',
#    'name': 'AFTER',
#    'source': 'E23',
#    'source_group': 11,
#    'source_name': ' pain',
#    'target': 'E78',
#    'target_group': 11,
#    'target_name': ' fistula',
#    'value': None},
#   {'id': 'R76',
#    'name': 'MODIFY',
#    'source': 'E24',
#    'source_group': 35,
#    'source_name': ' had been present for a year',
#    'target': 'E78',
#    'target_group': 11,
#    'target_name': ' fistula',
#    'value': 4},
#   {'id': 'R77',
#    'name': 'AFTER',
#    'source': 'E27',
#    'source_group': 11,
#    'source_name': ' stricture',
#    'target': 'E26',
#    'target_group': 11,
#    'target_name': ' fistula',
#    'value': None},
#   {'id': 'R78',
#    'name': 'MODIFY',
#    'source': 'E25',
#    'source_group': 35,
#    'source_name': ' of at least 2 years duration',
#    'target': 'E26',
#    'target_group': 11,
#    'target_name': ' fistula',
#    'value': 4},
#   {'id': 'R79',
#    'name': 'BEFORE',
#    'source': 'E26',
#    'source_group': 11,
#    'source_name': ' fistula',
#    'target': 'E29',
#    'target_group': 37,
#    'target_name': ' azathioprine',
#    'value': 3},
#   {'id': 'R80',
#    'name': 'BEFORE',
#    'source': 'E32',
#    'source_group': 12,
#    'source_name': ' a year earlier',
#    'target': 'E33',
#    'target_group': 11,
#    'target_name': ' no extra-intestinal manifestations',
#    'value': 3},
#   {'id': 'R81',
#    'name': 'BEFORE',
#    'source': 'E33',
#    'source_group': 11,
#    'source_name': ' no extra-intestinal manifestations',
#    'target': 'E34',
#    'target_group': 22,
#    'target_name': ' admission',
#    'value': 3},
#   {'id': 'R82',
#    'name': 'MODIFY',
#    'source': 'T66',
#    'source_group': 17,
#    'source_name': ' hospital',
#    'target': 'E34',
#    'target_group': 22,
#    'target_name': ' admission',
#    'value': 4},
#   {'id': 'R83',
#    'name': 'MODIFY',
#    'source': 'T73',
#    'source_group': 28,
#    'source_name': ' normal',
#    'target': 'E38',
#    'target_group': 38,
#    'target_name': ' cardio-respiratory examination',
#    'value': 4},
#   {'id': 'R84',
#    'name': 'MODIFY',
#    'source': 'T74',
#    'source_group': 7,
#    'source_name': ' abdomen',
#    'target': 'E40',
#    'target_group': 11,
#    'target_name': ' tender',
#    'value': 4},
#   {'id': 'R37',
#    'name': 'MODIFY',
#    'source': 'T78',
#    'source_group': 27,
#    'source_name': ' without guarding',
#    'target': 'E40',
#    'target_group': 11,
#    'target_name': ' tender',
#    'value': 4},
#   {'id': 'R38',
#    'name': 'MODIFY',
#    'source': 'T79',
#    'source_group': 27,
#    'source_name': ' 1404 without rebound tenderness',
#    'target': 'E40',
#    'target_group': 11,
#    'target_name': ' tender',
#    'value': 4},
#   {'id': 'R85',
#    'name': 'MODIFY',
#    'source': 'T83',
#    'source_group': 7,
#    'source_name': ' elbows',
#    'target': 'E43',
#    'target_group': 38,
#    'target_name': ' Examination of the skin',
#    'value': 4},
#   {'id': 'R86',
#    'name': 'MODIFY',
#    'source': 'T84',
#    'source_group': 7,
#    'source_name': ' ankles',
#    'target': 'E43',
#    'target_group': 38,
#    'target_name': ' Examination of the skin',
#    'value': 4},
#   {'id': 'R87',
#    'name': 'MODIFY',
#    'source': 'T85',
#    'source_group': 7,
#    'source_name': ' feet',
#    'target': 'E43',
#    'target_group': 38,
#    'target_name': ' Examination of the skin',
#    'value': 4},
#   {'id': 'R88',
#    'name': 'BEFORE',
#    'source': 'E46',
#    'source_group': 11,
#    'source_name': ' synovitis',
#    'target': 'E48',
#    'target_group': 38,
#    'target_name': ' laboratory tests',
#    'value': 3},
#   {'id': 'R89',
#    'name': 'MODIFY',
#    'source': 'T109',
#    'source_group': 28,
#    'source_name': ' normal',
#    'target': 'E58',
#    'target_group': 38,
#    'target_name': ' microscopy',
#    'value': 4},
#   {'id': 'R90',
#    'name': 'MODIFY',
#    'source': 'T109',
#    'source_group': 28,
#    'source_name': ' normal',
#    'target': 'E57',
#    'target_group': 38,
#    'target_name': ' urine analysis',
#    'value': 4},
#   {'id': 'R91',
#    'name': 'MODIFY',
#    'source': 'T109',
#    'source_group': 28,
#    'source_name': ' normal',
#    'target': 'E56',
#    'target_group': 38,
#    'target_name': ' complement',
#    'value': 4},
#   {'id': 'R92',
#    'name': 'MODIFY',
#    'source': 'T109',
#    'source_group': 28,
#    'source_name': ' normal',
#    'target': 'E55',
#    'target_group': 38,
#    'target_name': ' electrolytes',
#    'value': 4},
#   {'id': 'R93',
#    'name': 'MODIFY',
#    'source': 'T109',
#    'source_group': 28,
#    'source_name': ' normal',
#    'target': 'E54',
#    'target_group': 38,
#    'target_name': ' Urea',
#    'value': 4},
#   {'id': 'R94',
#    'name': 'MODIFY',
#    'source': 'T110',
#    'source_group': 28,
#    'source_name': ' negative',
#    'target': 'E60',
#    'target_group': 38,
#    'target_name': ' Rheumatoid factor',
#    'value': 4},
#   {'id': 'R95',
#    'name': 'MODIFY',
#    'source': 'T110',
#    'source_group': 28,
#    'source_name': ' negative',
#    'target': 'E61',
#    'target_group': 38,
#    'target_name': ' cytoplasmic antibodies',
#    'value': 4},
#   {'id': 'R96',
#    'name': 'MODIFY',
#    'source': 'T110',
#    'source_group': 28,
#    'source_name': ' negative',
#    'target': 'E75',
#    'target_group': 38,
#    'target_name': ' cryoglobulins',
#    'value': 4},
#   {'id': 'R97',
#    'name': 'MODIFY',
#    'source': 'T110',
#    'source_group': 28,
#    'source_name': ' negative',
#    'target': 'E76',
#    'target_group': 38,
#    'target_name': ' Hepatitis B and C serology',
#    'value': 4},
#   {'id': 'R98',
#    'name': 'BEFORE',
#    'source': 'E76',
#    'source_group': 38,
#    'source_name': ' Hepatitis B and C serology',
#    'target': 'E62',
#    'target_group': 38,
#    'target_name': ' echocardiogram',
#    'value': 3},
#   {'id': 'R99',
#    'name': 'BEFORE',
#    'source': 'E64',
#    'source_group': 38,
#    'source_name': ' multiple blood cultures',
#    'target': 'E65',
#    'target_group': 38,
#    'target_name': ' biopsy',
#    'value': 3},
#   {'id': 'R100',
#    'name': 'MODIFY',
#    'source': 'T124',
#    'source_group': 7,
#    'source_name': ' infiltrate',
#    'target': 'E65',
#    'target_group': 38,
#    'target_name': ' biopsy',
#    'value': 4},
#   {'id': 'R101',
#    'name': 'MODIFY',
#    'source': 'T125',
#    'source_group': 7,
#    'source_name': ' neutrophils',
#    'target': 'T124',
#    'target_group': 7,
#    'target_name': ' infiltrate',
#    'value': 4},
#   {'id': 'R102',
#    'name': 'BEFORE',
#    'source': 'E66',
#    'source_group': 34,
#    'source_name': ' vasculitis',
#    'target': 'E68',
#    'target_group': 37,
#    'target_name': ' prednisolone',
#    'value': 3},
#   {'id': 'R103',
#    'name': 'BEFORE',
#    'source': 'E68',
#    'source_group': 37,
#    'source_name': ' prednisolone',
#    'target': 'E69',
#    'target_group': 11,
#    'target_name': ' resolution of all features',
#    'value': 3},
#   {'id': 'R104',
#    'name': 'BEFORE',
#    'source': 'E69',
#    'source_group': 11,
#    'source_name': ' resolution of all features',
#    'target': 'E70',
#    'target_group': 37,
#    'target_name': ' prednisolone',
#    'value': 3},
#   {'id': 'R105',
#    'name': 'BEFORE',
#    'source': 'E70',
#    'source_group': 37,
#    'source_name': ' prednisolone',
#    'target': 'E72',
#    'target_group': 11,
#    'target_name': ' without any recurrence',
#    'value': 3},
#   {'id': 'R106',
#    'name': 'MODIFY',
#    'source': 'E71',
#    'source_group': 35,
#    'source_name': ' over the following 3 years',
#    'target': 'E72',
#    'target_group': 11,
#    'target_name': ' without any recurrence',
#    'value': 4}],
#  'nodes': [{'group': 10, 'id': 'T1', 'name': ' 23 year old', 'type': 'Age'},
#   {'group': 25, 'id': 'T2', 'name': ' white', 'type': 'Ethnicity'},
#   {'group': 6, 'id': 'T3', 'name': ' male', 'type': 'Gender'},
#   {'group': 13,
#    'id': 'T4',
#    'name': " 4 year history of Crohn's disease",
#    'type': 'History'},
#   {'group': 34,
#    'id': 'T5',
#    'name': " Crohn's disease",
#    'type': 'Disease_disorder'},
#   {'group': 35, 'id': 'T6', 'name': ' 4 year', 'type': 'Duration'},
#   {'group': 11, 'id': 'T7', 'name': ' malaise', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'T8', 'name': ' fever', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'T9', 'name': ' pain', 'type': 'Sign_symptom'},
#   {'group': 7,
#    'id': 'T10',
#    'name': ' abdominal',
#    'type': 'Biological_structure'},
#   {'group': 11, 'id': 'T11', 'name': ' vomiting', 'type': 'Sign_symptom'},
#   {'group': 7, 'id': 'T12', 'name': ' stomal', 'type': 'Biological_structure'},
#   {'group': 11, 'id': 'T13', 'name': ' diarrhoea', 'type': 'Sign_symptom'},
#   {'group': 35, 'id': 'T14', 'name': ' two day', 'type': 'Duration'},
#   {'group': 11, 'id': 'T15', 'name': ' pains', 'type': 'Sign_symptom'},
#   {'group': 7, 'id': 'T16', 'name': ' joint', 'type': 'Biological_structure'},
#   {'group': 7,
#    'id': 'T17',
#    'name': ' shoulders',
#    'type': 'Biological_structure'},
#   {'group': 7, 'id': 'T18', 'name': ' elbows', 'type': 'Biological_structure'},
#   {'group': 7, 'id': 'T19', 'name': ' wrists', 'type': 'Biological_structure'},
#   {'group': 7,
#    'id': 'T20',
#    'name': ' metacarpophalangeals',
#    'type': 'Biological_structure'},
#   {'group': 7, 'id': 'T21', 'name': ' knees', 'type': 'Biological_structure'},
#   {'group': 7, 'id': 'T22', 'name': ' ankles', 'type': 'Biological_structure'},
#   {'group': 11, 'id': 'T23', 'name': ' rash', 'type': 'Sign_symptom'},
#   {'group': 7, 'id': 'T24', 'name': ' elbows', 'type': 'Biological_structure'},
#   {'group': 7, 'id': 'T25', 'name': ' ankles', 'type': 'Biological_structure'},
#   {'group': 7, 'id': 'T26', 'name': ' feet', 'type': 'Biological_structure'},
#   {'group': 11, 'id': 'T27', 'name': ' macules', 'type': 'Sign_symptom'},
#   {'group': 27,
#    'id': 'T28',
#    'name': ' erythematous',
#    'type': 'Detailed_description'},
#   {'group': 11, 'id': 'T29', 'name': ' lesions', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'T30', 'name': ' crusting', 'type': 'Sign_symptom'},
#   {'group': 27,
#    'id': 'T31',
#    'name': ' vesico-pustular',
#    'type': 'Detailed_description'},
#   {'group': 13,
#    'id': 'T32',
#    'name': ' no history of sexual exposure',
#    'type': 'History'},
#   {'group': 11, 'id': 'T33', 'name': ' infection', 'type': 'Sign_symptom'},
#   {'group': 37,
#    'id': 'T34',
#    'name': ' no regular medication',
#    'type': 'Medication'},
#   {'group': 37, 'id': 'T35', 'name': ' Pentasa', 'type': 'Medication'},
#   {'group': 12, 'id': 'T36', 'name': ' 4 months earlier', 'type': 'Date'},
#   {'group': 12, 'id': 'T37', 'name': ' One month earlier', 'type': 'Date'},
#   {'group': 33,
#    'id': 'T38',
#    'name': ' laparotomy',
#    'type': 'Therapeutic_procedure'},
#   {'group': 11, 'id': 'T39', 'name': ' fistula', 'type': 'Sign_symptom'},
#   {'group': 27,
#    'id': 'T40',
#    'name': ' ileo-cutaneous',
#    'type': 'Detailed_description'},
#   {'group': 27,
#    'id': 'T41',
#    'name': ' complex',
#    'type': 'Detailed_description'},
#   {'group': 27,
#    'id': 'T42',
#    'name': ' blind tracts',
#    'type': 'Detailed_description'},
#   {'group': 12, 'id': 'T43', 'name': ' two weeks earlier', 'type': 'Date'},
#   {'group': 33,
#    'id': 'T44',
#    'name': ' ileostomy',
#    'type': 'Therapeutic_procedure'},
#   {'group': 27,
#    'id': 'T45',
#    'name': ' defunctioning',
#    'type': 'Detailed_description'},
#   {'group': 11, 'id': 'T46', 'name': ' pain', 'type': 'Sign_symptom'},
#   {'group': 7,
#    'id': 'T47',
#    'name': ' abdominal',
#    'type': 'Biological_structure'},
#   {'group': 27,
#    'id': 'T48',
#    'name': ' persistent',
#    'type': 'Detailed_description'},
#   {'group': 7,
#    'id': 'T50',
#    'name': ' cutaneous',
#    'type': 'Biological_structure'},
#   {'group': 35,
#    'id': 'T51',
#    'name': ' had been present for a year',
#    'type': 'Duration'},
#   {'group': 35,
#    'id': 'T52',
#    'name': ' of at least 2 years duration',
#    'type': 'Duration'},
#   {'group': 11, 'id': 'T53', 'name': ' fistula', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'T54', 'name': ' stricture', 'type': 'Sign_symptom'},
#   {'group': 7, 'id': 'T55', 'name': ' ileal', 'type': 'Biological_structure'},
#   {'group': 27,
#    'id': 'T56',
#    'name': ' terminal',
#    'type': 'Detailed_description'},
#   {'group': 7,
#    'id': 'T57',
#    'name': ' ileo-rectal',
#    'type': 'Biological_structure'},
#   {'group': 1, 'id': 'T58', 'name': ' bowel disease', 'type': 'Coreference'},
#   {'group': 37, 'id': 'T59', 'name': ' azathioprine', 'type': 'Medication'},
#   {'group': 37,
#    'id': 'T60',
#    'name': ' corticosteroiods',
#    'type': 'Medication'},
#   {'group': 37, 'id': 'T61', 'name': ' Infliximab', 'type': 'Medication'},
#   {'group': 12, 'id': 'T62', 'name': ' a year earlier', 'type': 'Date'},
#   {'group': 24, 'id': 'T63', 'name': ' three infusions', 'type': 'Dosage'},
#   {'group': 11,
#    'id': 'T64',
#    'name': ' no extra-intestinal manifestations',
#    'type': 'Sign_symptom'},
#   {'group': 22, 'id': 'T65', 'name': ' admission', 'type': 'Activity'},
#   {'group': 17,
#    'id': 'T66',
#    'name': ' hospital',
#    'type': 'Nonbiological_location'},
#   {'group': 11, 'id': 'T67', 'name': ' thin', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'T68', 'name': ' afebrile', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'T69', 'name': ' tachycardia', 'type': 'Sign_symptom'},
#   {'group': 27,
#    'id': 'T70',
#    'name': ' resting',
#    'type': 'Detailed_description'},
#   {'group': 16, 'id': 'T71', 'name': ' 125/minute', 'type': 'Lab_value'},
#   {'group': 38,
#    'id': 'T72',
#    'name': ' cardio-respiratory examination',
#    'type': 'Diagnostic_procedure'},
#   {'group': 7,
#    'id': 'T74',
#    'name': ' abdomen',
#    'type': 'Biological_structure'},
#   {'group': 11, 'id': 'T75', 'name': ' tender', 'type': 'Sign_symptom'},
#   {'group': 2, 'id': 'T76', 'name': ' minimally', 'type': 'Severity'},
#   {'group': 7,
#    'id': 'T77',
#    'name': ' ileostomy',
#    'type': 'Biological_structure'},
#   {'group': 38,
#    'id': 'T80',
#    'name': ' Examination of the skin',
#    'type': 'Diagnostic_procedure'},
#   {'group': 11, 'id': 'T81', 'name': ' pustules', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'T82', 'name': ' crusts', 'type': 'Sign_symptom'},
#   {'group': 7, 'id': 'T83', 'name': ' elbows', 'type': 'Biological_structure'},
#   {'group': 7, 'id': 'T84', 'name': ' ankles', 'type': 'Biological_structure'},
#   {'group': 7, 'id': 'T85', 'name': ' feet', 'type': 'Biological_structure'},
#   {'group': 11, 'id': 'T86', 'name': ' synovitis', 'type': 'Sign_symptom'},
#   {'group': 7, 'id': 'T87', 'name': ' wrists', 'type': 'Biological_structure'},
#   {'group': 4,
#    'id': 'T88',
#    'name': ' The buttocks were spared.',
#    'type': 'Other_event'},
#   {'group': 7,
#    'id': 'T89',
#    'name': ' proximal interphalangeal',
#    'type': 'Biological_structure'},
#   {'group': 7,
#    'id': 'T90',
#    'name': ' metacarpophalangeal',
#    'type': 'Biological_structure'},
#   {'group': 7, 'id': 'T91', 'name': ' joints', 'type': 'Biological_structure'},
#   {'group': 7,
#    'id': 'T92',
#    'name': ' both ankles',
#    'type': 'Biological_structure'},
#   {'group': 38,
#    'id': 'T93',
#    'name': ' laboratory tests',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'T94',
#    'name': ' haemoglobin',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'T95',
#    'name': ' white blood count',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'T96',
#    'name': ' platelets',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'T97',
#    'name': ' C- reactive protein',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'T98',
#    'name': ' erythrocyte sedimentation rate',
#    'type': 'Diagnostic_procedure'},
#   {'group': 16, 'id': 'T99', 'name': ' 13.1 gm/dl', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T100', 'name': ' 15.8 × 109/L', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T101', 'name': ' 585 × 109/L', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T102', 'name': ' 37.7 mg/L', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T103', 'name': ' 69 mm/hr', 'type': 'Lab_value'},
#   {'group': 38, 'id': 'T104', 'name': ' Urea', 'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'T105',
#    'name': ' electrolytes',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'T106',
#    'name': ' complement',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'T107',
#    'name': ' urine analysis',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'T108',
#    'name': ' microscopy',
#    'type': 'Diagnostic_procedure'},
#   {'group': 28,
#    'id': 'T110',
#    'name': ' negative',
#    'type': 'Qualitative_concept'},
#   {'group': 38,
#    'id': 'T111',
#    'name': ' Rheumatoid factor',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'T113',
#    'name': ' echocardiogram',
#    'type': 'Diagnostic_procedure'},
#   {'group': 7,
#    'id': 'T114',
#    'name': ' Transthoracic',
#    'type': 'Biological_structure'},
#   {'group': 11,
#    'id': 'T115',
#    'name': ' no signs of endocarditis',
#    'type': 'Sign_symptom'},
#   {'group': 38,
#    'id': 'T116',
#    'name': ' multiple blood cultures',
#    'type': 'Diagnostic_procedure'},
#   {'group': 28,
#    'id': 'T117',
#    'name': ' sterile',
#    'type': 'Qualitative_concept'},
#   {'group': 38,
#    'id': 'T118',
#    'name': ' biopsy',
#    'type': 'Diagnostic_procedure'},
#   {'group': 7, 'id': 'T119', 'name': ' skin', 'type': 'Biological_structure'},
#   {'group': 7,
#    'id': 'T120',
#    'name': ' perivascular',
#    'type': 'Biological_structure'},
#   {'group': 7,
#    'id': 'T121',
#    'name': ' lymphohistiocytic',
#    'type': 'Biological_structure'},
#   {'group': 34,
#    'id': 'T122',
#    'name': ' vasculitis',
#    'type': 'Disease_disorder'},
#   {'group': 27,
#    'id': 'T123',
#    'name': ' leukocytoclastic',
#    'type': 'Detailed_description'},
#   {'group': 7,
#    'id': 'T124',
#    'name': ' infiltrate',
#    'type': 'Biological_structure'},
#   {'group': 7,
#    'id': 'T125',
#    'name': ' neutrophils',
#    'type': 'Biological_structure'},
#   {'group': 11, 'id': 'T126', 'name': ' necrosis', 'type': 'Sign_symptom'},
#   {'group': 27,
#    'id': 'T127',
#    'name': ' fibrinoid',
#    'type': 'Detailed_description'},
#   {'group': 7,
#    'id': 'T128',
#    'name': ' vessels',
#    'type': 'Biological_structure'},
#   {'group': 37, 'id': 'T129', 'name': ' prednisolone', 'type': 'Medication'},
#   {'group': 24, 'id': 'T130', 'name': ' 60 mg', 'type': 'Dosage'},
#   {'group': 24, 'id': 'T131', 'name': ' per day', 'type': 'Dosage'},
#   {'group': 11,
#    'id': 'T132',
#    'name': ' resolution of all features',
#    'type': 'Sign_symptom'},
#   {'group': 27,
#    'id': 'T133',
#    'name': ' complete',
#    'type': 'Detailed_description'},
#   {'group': 27,
#    'id': 'T134',
#    'name': ' prompt',
#    'type': 'Detailed_description'},
#   {'group': 37, 'id': 'T135', 'name': ' prednisolone', 'type': 'Medication'},
#   {'group': 35,
#    'id': 'T136',
#    'name': ' over the following 3 years',
#    'type': 'Duration'},
#   {'group': 11,
#    'id': 'T137',
#    'name': ' without any recurrence',
#    'type': 'Sign_symptom'},
#   {'group': 35,
#    'id': 'T138',
#    'name': ' over the course of one month',
#    'type': 'Duration'},
#   {'group': 22, 'id': 'T139', 'name': ' tapered', 'type': 'Activity'},
#   {'group': 38,
#    'id': 'T112',
#    'name': ' cytoplasmic antibodies',
#    'type': 'Diagnostic_procedure'},
#   {'group': 27,
#    'id': 'T140',
#    'name': ' antineutrophil',
#    'type': 'Detailed_description'},
#   {'group': 27,
#    'id': 'T141',
#    'name': ' antinuclear',
#    'type': 'Detailed_description'},
#   {'group': 38,
#    'id': 'T142',
#    'name': ' cryoglobulins',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'T143',
#    'name': ' Hepatitis B and C serology',
#    'type': 'Diagnostic_procedure'},
#   {'group': 22, 'id': 'T144', 'name': ' presented', 'type': 'Activity'},
#   {'group': 11, 'id': 'T49', 'name': ' fistula', 'type': 'Sign_symptom'},
#   {'group': 28, 'id': 'T73', 'name': ' normal', 'type': 'Qualitative_concept'},
#   {'group': 27,
#    'id': 'T78',
#    'name': ' without guarding',
#    'type': 'Detailed_description'},
#   {'group': 27,
#    'id': 'T79',
#    'name': ' 1404 without rebound tenderness',
#    'type': 'Detailed_description'},
#   {'group': 28,
#    'id': 'T109',
#    'name': ' normal',
#    'type': 'Qualitative_concept'},
#   {'group': 34,
#    'id': 'E1',
#    'name': " Crohn's disease",
#    'type': 'Disease_disorder'},
#   {'group': 35, 'id': 'E2', 'name': ' 4 year', 'type': 'Duration'},
#   {'group': 11, 'id': 'E3', 'name': ' malaise', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E4', 'name': ' fever', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E5', 'name': ' pain', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E6', 'name': ' vomiting', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E7', 'name': ' diarrhoea', 'type': 'Sign_symptom'},
#   {'group': 35, 'id': 'E8', 'name': ' two day', 'type': 'Duration'},
#   {'group': 11, 'id': 'E9', 'name': ' pains', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E10', 'name': ' rash', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E11', 'name': ' macules', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E12', 'name': ' lesions', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E13', 'name': ' crusting', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E14', 'name': ' infection', 'type': 'Sign_symptom'},
#   {'group': 37,
#    'id': 'E15',
#    'name': ' no regular medication',
#    'type': 'Medication'},
#   {'group': 37, 'id': 'E16', 'name': ' Pentasa', 'type': 'Medication'},
#   {'group': 12, 'id': 'E17', 'name': ' 4 months earlier', 'type': 'Date'},
#   {'group': 12, 'id': 'E18', 'name': ' One month earlier', 'type': 'Date'},
#   {'group': 33,
#    'id': 'E19',
#    'name': ' laparotomy',
#    'type': 'Therapeutic_procedure'},
#   {'group': 11, 'id': 'E20', 'name': ' fistula', 'type': 'Sign_symptom'},
#   {'group': 12, 'id': 'E21', 'name': ' two weeks earlier', 'type': 'Date'},
#   {'group': 33,
#    'id': 'E22',
#    'name': ' ileostomy',
#    'type': 'Therapeutic_procedure'},
#   {'group': 11, 'id': 'E23', 'name': ' pain', 'type': 'Sign_symptom'},
#   {'group': 35,
#    'id': 'E24',
#    'name': ' had been present for a year',
#    'type': 'Duration'},
#   {'group': 35,
#    'id': 'E25',
#    'name': ' of at least 2 years duration',
#    'type': 'Duration'},
#   {'group': 11, 'id': 'E26', 'name': ' fistula', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E27', 'name': ' stricture', 'type': 'Sign_symptom'},
#   {'group': 1, 'id': 'E28', 'name': ' bowel disease', 'type': 'Coreference'},
#   {'group': 37, 'id': 'E29', 'name': ' azathioprine', 'type': 'Medication'},
#   {'group': 37,
#    'id': 'E30',
#    'name': ' corticosteroiods',
#    'type': 'Medication'},
#   {'group': 37, 'id': 'E31', 'name': ' Infliximab', 'type': 'Medication'},
#   {'group': 12, 'id': 'E32', 'name': ' a year earlier', 'type': 'Date'},
#   {'group': 11,
#    'id': 'E33',
#    'name': ' no extra-intestinal manifestations',
#    'type': 'Sign_symptom'},
#   {'group': 22, 'id': 'E34', 'name': ' admission', 'type': 'Activity'},
#   {'group': 11, 'id': 'E35', 'name': ' thin', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E36', 'name': ' afebrile', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E37', 'name': ' tachycardia', 'type': 'Sign_symptom'},
#   {'group': 38,
#    'id': 'E38',
#    'name': ' cardio-respiratory examination',
#    'type': 'Diagnostic_procedure'},
#   {'group': 11, 'id': 'E40', 'name': ' tender', 'type': 'Sign_symptom'},
#   {'group': 38,
#    'id': 'E43',
#    'name': ' Examination of the skin',
#    'type': 'Diagnostic_procedure'},
#   {'group': 11, 'id': 'E44', 'name': ' pustules', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E45', 'name': ' crusts', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E46', 'name': ' synovitis', 'type': 'Sign_symptom'},
#   {'group': 4,
#    'id': 'E47',
#    'name': ' The buttocks were spared.',
#    'type': 'Other_event'},
#   {'group': 38,
#    'id': 'E48',
#    'name': ' laboratory tests',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E49',
#    'name': ' haemoglobin',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E50',
#    'name': ' white blood count',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E51',
#    'name': ' platelets',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E52',
#    'name': ' C- reactive protein',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E53',
#    'name': ' erythrocyte sedimentation rate',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E54', 'name': ' Urea', 'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E55',
#    'name': ' electrolytes',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E56',
#    'name': ' complement',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E57',
#    'name': ' urine analysis',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E58',
#    'name': ' microscopy',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E60',
#    'name': ' Rheumatoid factor',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E62',
#    'name': ' echocardiogram',
#    'type': 'Diagnostic_procedure'},
#   {'group': 11,
#    'id': 'E63',
#    'name': ' no signs of endocarditis',
#    'type': 'Sign_symptom'},
#   {'group': 38,
#    'id': 'E64',
#    'name': ' multiple blood cultures',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E65',
#    'name': ' biopsy',
#    'type': 'Diagnostic_procedure'},
#   {'group': 34,
#    'id': 'E66',
#    'name': ' vasculitis',
#    'type': 'Disease_disorder'},
#   {'group': 11, 'id': 'E67', 'name': ' necrosis', 'type': 'Sign_symptom'},
#   {'group': 37, 'id': 'E68', 'name': ' prednisolone', 'type': 'Medication'},
#   {'group': 11,
#    'id': 'E69',
#    'name': ' resolution of all features',
#    'type': 'Sign_symptom'},
#   {'group': 37, 'id': 'E70', 'name': ' prednisolone', 'type': 'Medication'},
#   {'group': 35,
#    'id': 'E71',
#    'name': ' over the following 3 years',
#    'type': 'Duration'},
#   {'group': 11,
#    'id': 'E72',
#    'name': ' without any recurrence',
#    'type': 'Sign_symptom'},
#   {'group': 35,
#    'id': 'E73',
#    'name': ' over the course of one month',
#    'type': 'Duration'},
#   {'group': 22, 'id': 'E74', 'name': ' tapered', 'type': 'Activity'},
#   {'group': 38,
#    'id': 'E61',
#    'name': ' cytoplasmic antibodies',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E75',
#    'name': ' cryoglobulins',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E76',
#    'name': ' Hepatitis B and C serology',
#    'type': 'Diagnostic_procedure'},
#   {'group': 22, 'id': 'E77', 'name': ' presented', 'type': 'Activity'},
#   {'group': 11, 'id': 'E78', 'name': ' fistula', 'type': 'Sign_symptom'}]}
