# %% [markdown]
# ### Network-Data

# %% [markdown]
# Data Preparation

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from time import time

# %%
% matplotlib inline
import json

# %% [markdown]
# ### Get all data

# %% [markdown]
# #### Get T and E and R data :

# %%
"""============================================================
This class helps to read data from 'sample.ann' files to create
nodes and edges for network and graph analysis

By: Sigdel D.       Data-2018-Jan-10
==============================================================="""



class DataReader(object):
    
    """Llist: list of lines of files
       t_dict :  dictionary of T-terms
       e_dict : dictionary of e-terms
       r_dict : dictionary of r-terms
       Nodes: List of nodes
       Edges : List of edges"""
    
    
    def __init__(self,input_file):
        #Input file shoulsd be provided
        self.input_file = input_file
        self.Llist = []
        self.t_dict = {}  
        self.e_dict = {}
        self.r_dict = {}
        self.node_dict ={}
        self.Nodes  =[]
        self.Edges = []
        
        
        self.group = ['Coreference', 'Severity', 'Occupation', 'Other_event',\
                      'Frequency', 'Gender', 'Biological_structure', 'Volume',\
                      'Biological_attribute', 'Age', 'Sign_symptom', 'Date',\
                      'History', 'Time', 'Shape', 'Lab_value', 'Nonbiological_location',\
                      'Administration', 'Distance', 'Other_entity', 'Height',\
                      'Activity', 'Family_history', 'Dosage', 'Ethnicity',\
                      'Subject', 'Detailed_description', 'Qualitative_concept',\
                      'Texture', 'Area', 'Weight', 'Quantitative_concept', \
                      'Therapeutic_procedure', 'Disease_disorder', 'Duration',\
                      'Color', 'Medication', 'Diagnostic_procedure']
        
        
        self.relations = ['BEFORE','MODIFY','SUB_PROCEDURE','IDENTICAL','AFTER',\
                        'OVERLAP', 'CAUSE','CO-OCCURANCE','DECREASE_TO',\
                        'DECREASE_FROM', 'INCREASE_FROM','INCREASE_TO']
        
        
        
        
    # function to sum charcters in the list    
    def sum_chr_items(self, items):
        st =""
        for item in items:
            st = st+" "+item
        return st
    
    
    
    # Line of text is converted to list
    def line_to_list(self):
        with open(self.input_file) as f:
            for line in f:
                self.Llist.append(line.split())
                
                
                
                
    def find_group(self,g):
        for k,item in enumerate(self.group):
            if item == g:
                return(k+1)
            
            
                
    def find_edg_value(self,eg):
        for k,item in enumerate(self.relations):
            if item == eg:
                return(2+(k+1))
            
            
    def set_tdata(self):
        for item in self.Llist:
            if item[0][0] =="T":
                t_key = item[0]
                t_type = item[1]
                t_val = self.sum_chr_items(item[4:])
                
                self.t_dict.update({t_key:[t_type,t_val]})
                
                self.node_dict.update({t_key:[t_type,t_val]})
                
                self.Nodes.append({"id":t_key,\
                              "type":t_type,\
                              "group":self.find_group(t_type),\
                              "name":t_val})
               
                    
                
                
                
    def set_edata(self):
        for item in self.Llist:            
            if item[0][0] =="E":
                t_key = item[1].split(':')[1]
                e_key = item[0]
                e_type = item[1].split(':')[0]
                e_val = self.t_dict[t_key][1]
                
                
                self.e_dict.update({e_key:[e_type,e_val]})
                
                self.node_dict.update({e_key:[e_type,e_val]})  
                
                for item in self.Nodes:
                    if item["id"] ==  t_key :
                        self.Nodes.remove(item)
                
                self.Nodes.append({"id":e_key,\
                            "type":e_type,\
                            "group":self.find_group(e_type),\
                            "name":e_val})
                
                
                
    def set_rdata(self):
        for item in self.Llist:           
            if item[0][0] =="R":
                r_key = item[0]
                rln = item[1]
                fm_id = item[2].split(":")[1]
                to_id = item[3].split(":")[1]
                fm_type = self.node_dict[fm_id][0]
                to_type = self.node_dict[to_id][0]
                fm_name = self.node_dict[fm_id][1]
                to_name = self.node_dict[to_id][1]
                
                self.r_dict.update({r_key:[rln,fm_id,to_id]}) 

                self.Edges.append({"id":r_key,\
                            "name":rln,\
                            "value":self.find_edg_value(rln),\
                            "source":fm_id,\
                            "source_name":fm_name,\
                            "source_group":self.find_group(fm_type),\
                            "target":to_id,\
                            "target_name":to_name,\
                            "target_group":self.find_group(to_type)})
                
                
                
                
    def set_sdata(self):
        for item in self.Llist: 
            if item[0][0] !="E":
                if item[0][0] !="R":
                    if item[0][0] !="T":
                        if item[0][0] =="*":
                            r_key = "ST"
                            rln = item[1]
                            ids = item[2:]
                            for  i in range(len(ids)):
                                for j in range(i,len(ids)):
                                    if i != j:
                                        fm_id  = ids[i]
                                        to_id = ids[j]
                                        fm_type = self.node_dict[fm_id][0]
                                        to_type = self.node_dict[to_id][0]
                                        fm_name = self.node_dict[fm_id][1]
                                        to_name = self.node_dict[to_id][1]
                                        
                                        
                                        self.Edges.append({"id":r_key,\
                                                    "name":rln,\
                                                    "value": self.find_edg_value(rln),\
                                                    "source":fm_id,\
                                                    "source_name":fm_name,\
                                                    "source_group":self.find_group(fm_type),\
                                                    "target":to_id,\
                                                    "target_name":to_name,\
                                                    "target_group":self.find_group(to_type)})
                
                
    
                
    def data_dumper(self,file_name,data):
            with open(file_name, 'w') as fp:
                json.dump(data, fp)
                
    
     
    def get_nodes(self,dump=False):
        self.line_to_list()
        self.set_tdata()
        self.set_edata()
        if dump:
            self.data_dumper(file_name = 'nodes.json',data = self.Nodes)
        return self.Nodes
    
    
    
    def get_edges(self, dump=False):
        self.set_rdata()
        self.set_sdata()
        if dump:
            self.data_dumper(file_name = 'edges.json',data = self.Edges)
        return self.Edges
    
    
    def get_data(self,fname,dump=False):
        all_data = {}
        nodes = self.get_nodes()
        edges = self.get_edges()
        
        all_data.update({'nodes':nodes,'links':edges })
        
        
        
        if dump:
            self.data_dumper(file_name = fname,data = all_data) 
        
        return all_data

# %%
PMID = "18561524"
DR = DataReader(PMID+".ann")
DR.get_data(PMID+".json", dump=True)
# Out:
# {'links': [{'id': 'R2',
#    'name': 'MODIFY',
#    'source': 'T8',
#    'source_group': 16,
#    'source_name': ' 40',
#    'target': 'E4',
#    'target_group': 38,
#    'target_name': ' body mass index',
#    'value': 4},
#   {'id': 'R3',
#    'name': 'MODIFY',
#    'source': 'T32',
#    'source_group': 16,
#    'source_name': ' 7.45',
#    'target': 'E22',
#    'target_group': 38,
#    'target_name': ' pH',
#    'value': 4},
#   {'id': 'R4',
#    'name': 'MODIFY',
#    'source': 'T36',
#    'source_group': 16,
#    'source_name': ' 3.55 kPa',
#    'target': 'E23',
#    'target_group': 38,
#    'target_name': ' pCO2',
#    'value': 4},
#   {'id': 'R5',
#    'name': 'MODIFY',
#    'source': 'T37',
#    'source_group': 16,
#    'source_name': ' 7.76 kPa',
#    'target': 'E24',
#    'target_group': 38,
#    'target_name': ' paO2',
#    'value': 4},
#   {'id': 'R6',
#    'name': 'MODIFY',
#    'source': 'T38',
#    'source_group': 16,
#    'source_name': ' −5.1 mmol/l',
#    'target': 'E25',
#    'target_group': 38,
#    'target_name': ' BE',
#    'value': 4},
#   {'id': 'R7',
#    'name': 'SUB_PROCEDURE',
#    'source': 'E22',
#    'source_group': 38,
#    'source_name': ' pH',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 5},
#   {'id': 'R8',
#    'name': 'SUB_PROCEDURE',
#    'source': 'E23',
#    'source_group': 38,
#    'source_name': ' pCO2',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 5},
#   {'id': 'R9',
#    'name': 'SUB_PROCEDURE',
#    'source': 'E24',
#    'source_group': 38,
#    'source_name': ' paO2',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 5},
#   {'id': 'R10',
#    'name': 'SUB_PROCEDURE',
#    'source': 'E25',
#    'source_group': 38,
#    'source_name': ' BE',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 5},
#   {'id': 'R11',
#    'name': 'MODIFY',
#    'source': 'T40',
#    'source_group': 28,
#    'source_name': ' not elevated',
#    'target': 'E26',
#    'target_group': 38,
#    'target_name': ' C-reactive protein',
#    'value': 4},
#   {'id': 'R12',
#    'name': 'MODIFY',
#    'source': 'T41',
#    'source_group': 7,
#    'source_name': ' chest',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 4},
#   {'id': 'R13',
#    'name': 'MODIFY',
#    'source': 'E28',
#    'source_group': 11,
#    'source_name': ' enlarged heart',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 4},
#   {'id': 'R14',
#    'name': 'MODIFY',
#    'source': 'T46',
#    'source_group': 27,
#    'source_name': ' unfractionated',
#    'target': 'E30',
#    'target_group': 37,
#    'target_name': ' heparin',
#    'value': 4},
#   {'id': 'R15',
#    'name': 'MODIFY',
#    'source': 'T47',
#    'source_group': 7,
#    'source_name': ' pulmonary',
#    'target': 'E31',
#    'target_group': 11,
#    'target_name': ' embolism',
#    'value': 4},
#   {'id': 'R16',
#    'name': 'MODIFY',
#    'source': 'T53',
#    'source_group': 28,
#    'source_name': ' rising',
#    'target': 'E35',
#    'target_group': 38,
#    'target_name': ' liver enzymes',
#    'value': 4},
#   {'id': 'R17',
#    'name': 'MODIFY',
#    'source': 'T60',
#    'source_group': 18,
#    'source_name': ' infusion',
#    'target': 'E39',
#    'target_group': 37,
#    'target_name': ' noradrenaline',
#    'value': 4},
#   {'id': 'R18',
#    'name': 'MODIFY',
#    'source': 'T66',
#    'source_group': 7,
#    'source_name': ' thoracic',
#    'target': 'E42',
#    'target_group': 38,
#    'target_name': ' computed tomography scan',
#    'value': 4},
#   {'id': 'R19',
#    'name': 'MODIFY',
#    'source': 'E43',
#    'source_group': 11,
#    'source_name': ' did not show pulmonary embolism',
#    'target': 'E42',
#    'target_group': 38,
#    'target_name': ' computed tomography scan',
#    'value': 4},
#   {'id': 'R20',
#    'name': 'MODIFY',
#    'source': 'T70',
#    'source_group': 19,
#    'source_name': ' 7 cm',
#    'target': 'E46',
#    'target_group': 38,
#    'target_name': ' left ventricular end diastolic diameter',
#    'value': 4},
#   {'id': 'R21',
#    'name': 'MODIFY',
#    'source': 'T73',
#    'source_group': 28,
#    'source_name': ' hypokinetic',
#    'target': 'T72',
#    'target_group': 7,
#    'target_name': ' left ventricle',
#    'value': 4},
#   {'id': 'R22',
#    'name': 'MODIFY',
#    'source': 'T74',
#    'source_group': 2,
#    'source_name': ' severely',
#    'target': 'T73',
#    'target_group': 28,
#    'target_name': ' hypokinetic',
#    'value': 4},
#   {'id': 'R23',
#    'name': 'MODIFY',
#    'source': 'T79',
#    'source_group': 28,
#    'source_name': ' elevated',
#    'target': 'E49',
#    'target_group': 38,
#    'target_name': ' left ventricular end diastolic pressure',
#    'value': 4},
#   {'id': 'R24',
#    'name': 'MODIFY',
#    'source': 'T81',
#    'source_group': 28,
#    'source_name': ' moderate',
#    'target': 'E50',
#    'target_group': 11,
#    'target_name': ' mitral regurgitation',
#    'value': 4},
#   {'id': 'R25',
#    'name': 'MODIFY',
#    'source': 'T83',
#    'source_group': 27,
#    'source_name': ' Intermittent',
#    'target': 'E51',
#    'target_group': 33,
#    'target_name': ' hemodialysis',
#    'value': 4},
#   {'id': 'R26',
#    'name': 'IDENTICAL',
#    'source': 'E53',
#    'source_group': 1,
#    'source_name': ' dialysis',
#    'target': 'E51',
#    'target_group': 33,
#    'target_name': ' hemodialysis',
#    'value': 6},
#   {'id': 'R27',
#    'name': 'MODIFY',
#    'source': 'T87',
#    'source_group': 28,
#    'source_name': ' deteriorated',
#    'target': 'E54',
#    'target_group': 38,
#    'target_name': ' renal function',
#    'value': 4},
#   {'id': 'R28',
#    'name': 'MODIFY',
#    'source': 'T88',
#    'source_group': 28,
#    'source_name': ' improved',
#    'target': 'E52',
#    'target_group': 38,
#    'target_name': ' liver function',
#    'value': 4},
#   {'id': 'R29',
#    'name': 'MODIFY',
#    'source': 'T89',
#    'source_group': 2,
#    'source_name': ' slightly',
#    'target': 'T88',
#    'target_group': 28,
#    'target_name': ' improved',
#    'value': 4},
#   {'id': 'R30',
#    'name': 'SUB_PROCEDURE',
#    'source': 'E55',
#    'source_group': 38,
#    'source_name': ' creatinine values',
#    'target': 'E54',
#    'target_group': 38,
#    'target_name': ' renal function',
#    'value': 5},
#   {'id': 'R31',
#    'name': 'MODIFY',
#    'source': 'T91',
#    'source_group': 28,
#    'source_name': ' increasing',
#    'target': 'E55',
#    'target_group': 38,
#    'target_name': ' creatinine values',
#    'value': 4},
#   {'id': 'R32',
#    'name': 'MODIFY',
#    'source': 'T94',
#    'source_group': 28,
#    'source_name': ' worsening',
#    'target': 'E57',
#    'target_group': 38,
#    'target_name': ' left ventricular systolic function',
#    'value': 4},
#   {'id': 'R33',
#    'name': 'MODIFY',
#    'source': 'T96',
#    'source_group': 16,
#    'source_name': ' 10%–12%',
#    'target': 'E58',
#    'target_group': 38,
#    'target_name': ' ejection fraction',
#    'value': 4},
#   {'id': 'R34',
#    'name': 'MODIFY',
#    'source': 'T99',
#    'source_group': 16,
#    'source_name': ' 30 mmHg',
#    'target': 'E60',
#    'target_group': 38,
#    'target_name': ' systolic pulmonary pressure',
#    'value': 4},
#   {'id': 'R35',
#    'name': 'MODIFY',
#    'source': 'T101',
#    'source_group': 27,
#    'source_name': ' dilated',
#    'target': 'E61',
#    'target_group': 34,
#    'target_name': ' cardiomyopathy',
#    'value': 4},
#   {'id': 'R36',
#    'name': 'MODIFY',
#    'source': 'T104',
#    'source_group': 7,
#    'source_name': ' liver',
#    'target': 'E63',
#    'target_group': 11,
#    'target_name': ' failure',
#    'value': 4},
#   {'id': 'R37',
#    'name': 'MODIFY',
#    'source': 'T105',
#    'source_group': 7,
#    'source_name': ' renal',
#    'target': 'E63',
#    'target_group': 11,
#    'target_name': ' failure',
#    'value': 4},
#   {'id': 'R38',
#    'name': 'CAUSE',
#    'source': 'E62',
#    'source_group': 11,
#    'source_name': ' low output failure',
#    'target': 'E63',
#    'target_group': 11,
#    'target_name': ' failure',
#    'value': 9},
#   {'id': 'R39',
#    'name': 'IDENTICAL',
#    'source': 'E64',
#    'source_group': 1,
#    'source_name': ' cardiomyopathy',
#    'target': 'E61',
#    'target_group': 34,
#    'target_name': ' cardiomyopathy',
#    'value': 6},
#   {'id': 'R40',
#    'name': 'MODIFY',
#    'source': 'T107',
#    'source_group': 27,
#    'source_name': ' drug-induced',
#    'target': 'E64',
#    'target_group': 1,
#    'target_name': ' cardiomyopathy',
#    'value': 4},
#   {'id': 'R41',
#    'name': 'MODIFY',
#    'source': 'T114',
#    'source_group': 28,
#    'source_name': ' negative',
#    'target': 'E70',
#    'target_group': 38,
#    'target_name': ' amyloid deposition',
#    'value': 4},
#   {'id': 'R42',
#    'name': 'MODIFY',
#    'source': 'T114',
#    'source_group': 28,
#    'source_name': ' negative',
#    'target': 'E69',
#    'target_group': 38,
#    'target_name': ' iron',
#    'value': 4},
#   {'id': 'R43',
#    'name': 'MODIFY',
#    'source': 'T114',
#    'source_group': 28,
#    'source_name': ' negative',
#    'target': 'E68',
#    'target_group': 38,
#    'target_name': ' immunological markers',
#    'value': 4},
#   {'id': 'R44',
#    'name': 'MODIFY',
#    'source': 'T114',
#    'source_group': 28,
#    'source_name': ' negative',
#    'target': 'E67',
#    'target_group': 38,
#    'target_name': ' Screening for infectious pathogens',
#    'value': 4},
#   {'id': 'R45',
#    'name': 'MODIFY',
#    'source': 'T118',
#    'source_group': 18,
#    'source_name': ' infusions',
#    'target': 'E72',
#    'target_group': 37,
#    'target_name': ' dobutamine',
#    'value': 4},
#   {'id': 'R46',
#    'name': 'MODIFY',
#    'source': 'T118',
#    'source_group': 18,
#    'source_name': ' infusions',
#    'target': 'E71',
#    'target_group': 37,
#    'target_name': ' noradrenaline',
#    'value': 4},
#   {'id': 'R47',
#    'name': 'IDENTICAL',
#    'source': 'E76',
#    'source_group': 1,
#    'source_name': ' noradrenaline',
#    'target': 'E71',
#    'target_group': 37,
#    'target_name': ' noradrenaline',
#    'value': 6},
#   {'id': 'R48',
#    'name': 'MODIFY',
#    'source': 'T125',
#    'source_group': 28,
#    'source_name': ' normal',
#    'target': 'E78',
#    'target_group': 38,
#    'target_name': ' Coronary angiography',
#    'value': 4},
#   {'id': 'R49',
#    'name': 'MODIFY',
#    'source': 'T127',
#    'source_group': 7,
#    'source_name': ' Endomyocardial',
#    'target': 'E79',
#    'target_group': 38,
#    'target_name': ' biopsy',
#    'value': 4},
#   {'id': 'R50',
#    'name': 'MODIFY',
#    'source': 'T128',
#    'source_group': 7,
#    'source_name': ' right ventricle',
#    'target': 'E79',
#    'target_group': 38,
#    'target_name': ' biopsy',
#    'value': 4},
#   {'id': 'R51',
#    'name': 'MODIFY',
#    'source': 'E80',
#    'source_group': 34,
#    'source_name': ' myocardial pathology',
#    'target': 'E79',
#    'target_group': 38,
#    'target_name': ' biopsy',
#    'value': 4},
#   {'id': 'R52',
#    'name': 'IDENTICAL',
#    'source': 'E81',
#    'source_group': 1,
#    'source_name': ' IABP',
#    'target': 'E73',
#    'target_group': 33,
#    'target_name': ' intraaortic balloon pump',
#    'value': 6},
#   {'id': 'R53',
#    'name': 'IDENTICAL',
#    'source': 'E82',
#    'source_group': 1,
#    'source_name': ' nitroprusside',
#    'target': 'E77',
#    'target_group': 37,
#    'target_name': ' nitroprusside',
#    'value': 6},
#   {'id': 'R55',
#    'name': 'MODIFY',
#    'source': 'T134',
#    'source_group': 28,
#    'source_name': ' normal',
#    'target': 'E84',
#    'target_group': 38,
#    'target_name': ' liver function',
#    'value': 4},
#   {'id': 'R56',
#    'name': 'MODIFY',
#    'source': 'T136',
#    'source_group': 28,
#    'source_name': ' improved',
#    'target': 'E85',
#    'target_group': 38,
#    'target_name': ' clinical situation',
#    'value': 4},
#   {'id': 'R57',
#    'name': 'MODIFY',
#    'source': 'T138',
#    'source_group': 28,
#    'source_name': ' improved',
#    'target': 'E86',
#    'target_group': 38,
#    'target_name': ' renal function',
#    'value': 4},
#   {'id': 'R58',
#    'name': 'MODIFY',
#    'source': 'T141',
#    'source_group': 16,
#    'source_name': ' 798',
#    'target': 'E88',
#    'target_group': 38,
#    'target_name': ' creatinine',
#    'value': 4},
#   {'id': 'R59',
#    'name': 'MODIFY',
#    'source': 'T142',
#    'source_group': 16,
#    'source_name': ' 98 μmol/l',
#    'target': 'E88',
#    'target_group': 38,
#    'target_name': ' creatinine',
#    'value': 4},
#   {'id': 'R60',
#    'name': 'MODIFY',
#    'source': 'T144',
#    'source_group': 16,
#    'source_name': ' 15%',
#    'target': 'E89',
#    'target_group': 38,
#    'target_name': ' EF',
#    'value': 4},
#   {'id': 'R61',
#    'name': 'MODIFY',
#    'source': 'T145',
#    'source_group': 28,
#    'source_name': ' reduced',
#    'target': 'E89',
#    'target_group': 38,
#    'target_name': ' EF',
#    'value': 4},
#   {'id': 'R62',
#    'name': 'CAUSE',
#    'source': 'E91',
#    'source_group': 11,
#    'source_name': ' adipose stature',
#    'target': 'E93',
#    'target_group': 22,
#    'target_name': ' denied',
#    'value': 9},
#   {'id': 'R63',
#    'name': 'CAUSE',
#    'source': 'E90',
#    'source_group': 11,
#    'source_name': ' behavioral problems',
#    'target': 'E93',
#    'target_group': 22,
#    'target_name': ' denied',
#    'value': 9},
#   {'id': 'R64',
#    'name': 'MODIFY',
#    'source': 'E93',
#    'source_group': 22,
#    'source_name': ' denied',
#    'target': 'E92',
#    'target_group': 33,
#    'target_name': ' heart transplant',
#    'value': 4},
#   {'id': 'R65',
#    'name': 'IDENTICAL',
#    'source': 'E94',
#    'source_group': 1,
#    'source_name': ' IABP',
#    'target': 'E73',
#    'target_group': 33,
#    'target_name': ' intraaortic balloon pump',
#    'value': 6},
#   {'id': 'R66',
#    'name': 'MODIFY',
#    'source': 'T156',
#    'source_group': 28,
#    'source_name': ' normal',
#    'target': 'E98',
#    'target_group': 38,
#    'target_name': ' liver and renal functions',
#    'value': 4},
#   {'id': 'R67',
#    'name': 'MODIFY',
#    'source': 'T163',
#    'source_group': 28,
#    'source_name': ' improved',
#    'target': 'E104',
#    'target_group': 38,
#    'target_name': ' clinical status',
#    'value': 4},
#   {'id': 'R68',
#    'name': 'MODIFY',
#    'source': 'T166',
#    'source_group': 16,
#    'source_name': ' 20%',
#    'target': 'E106',
#    'target_group': 38,
#    'target_name': ' EF',
#    'value': 4},
#   {'id': 'R70',
#    'name': 'MODIFY',
#    'source': 'T171',
#    'source_group': 28,
#    'source_name': ' improved',
#    'target': 'E108',
#    'target_group': 38,
#    'target_name': ' clinical status',
#    'value': 4},
#   {'id': 'R71',
#    'name': 'MODIFY',
#    'source': 'T177',
#    'source_group': 16,
#    'source_name': ' 30%–35%',
#    'target': 'E111',
#    'target_group': 38,
#    'target_name': ' EF',
#    'value': 4},
#   {'id': 'R72',
#    'name': 'MODIFY',
#    'source': 'T29',
#    'source_group': 16,
#    'source_name': ' 120/80 mmHg',
#    'target': 'E20',
#    'target_group': 38,
#    'target_name': ' blood pressure',
#    'value': 4},
#   {'id': 'R73',
#    'name': 'MODIFY',
#    'source': 'T58',
#    'source_group': 16,
#    'source_name': ' 90/60 mmHg',
#    'target': 'E38',
#    'target_group': 38,
#    'target_name': ' blood pressure',
#    'value': 4},
#   {'id': 'R74',
#    'name': 'MODIFY',
#    'source': 'T62',
#    'source_group': 16,
#    'source_name': ' 130/minute',
#    'target': 'E40',
#    'target_group': 38,
#    'target_name': ' heart rate',
#    'value': 4},
#   {'id': 'R75',
#    'name': 'MODIFY',
#    'source': 'T77',
#    'source_group': 16,
#    'source_name': ' 20%–25%',
#    'target': 'E47',
#    'target_group': 38,
#    'target_name': ' ejection fraction',
#    'value': 4},
#   {'id': 'R76',
#    'name': 'IDENTICAL',
#    'source': 'E2',
#    'source_group': 34,
#    'source_name': ' ADHD',
#    'target': 'E1',
#    'target_group': 34,
#    'target_name': ' attention-deficit hyperactivity disorder',
#    'value': 6},
#   {'id': 'R77',
#    'name': 'MODIFY',
#    'source': 'T173',
#    'source_group': 28,
#    'source_name': ' II',
#    'target': 'E109',
#    'target_group': 38,
#    'target_name': ' function class',
#    'value': 4},
#   {'id': 'R78',
#    'name': 'MODIFY',
#    'source': 'T174',
#    'source_group': 27,
#    'source_name': ' New York Heart Association',
#    'target': 'E109',
#    'target_group': 38,
#    'target_name': ' function class',
#    'value': 4},
#   {'id': 'R79',
#    'name': 'SUB_PROCEDURE',
#    'source': 'E112',
#    'source_group': 38,
#    'source_name': ' echocardiography',
#    'target': 'E111',
#    'target_group': 38,
#    'target_name': ' EF',
#    'value': 5},
#   {'id': 'R80',
#    'name': 'MODIFY',
#    'source': 'T154',
#    'source_group': 17,
#    'source_name': ' our hospital',
#    'target': 'E97',
#    'target_group': 22,
#    'target_name': ' transferred',
#    'value': 4},
#   {'id': 'R81',
#    'name': 'MODIFY',
#    'source': 'T169',
#    'source_group': 28,
#    'source_name': ' dilated',
#    'target': 'E105',
#    'target_group': 38,
#    'target_name': ' echocardiography',
#    'value': 4},
#   {'id': 'R69',
#    'name': 'MODIFY',
#    'source': 'T168',
#    'source_group': 7,
#    'source_name': ' left ventricle',
#    'target': 'E105',
#    'target_group': 38,
#    'target_name': ' echocardiography',
#    'value': 4},
#   {'id': 'R82',
#    'name': 'MODIFY',
#    'source': 'T55',
#    'source_group': 17,
#    'source_name': ' hospital',
#    'target': 'E36',
#    'target_group': 22,
#    'target_name': ' referred',
#    'value': 4},
#   {'id': 'R83',
#    'name': 'MODIFY',
#    'source': 'T21',
#    'source_group': 17,
#    'source_name': ' local hospital',
#    'target': 'E14',
#    'target_group': 22,
#    'target_name': ' admitted',
#    'value': 4},
#   {'id': 'R84',
#    'name': 'IDENTICAL',
#    'source': 'E11',
#    'source_group': 37,
#    'source_name': ' (Concerta®)',
#    'target': 'E10',
#    'target_group': 37,
#    'target_name': ' methylphenidate',
#    'value': 6},
#   {'id': 'R85',
#    'name': 'IDENTICAL',
#    'source': 'E8',
#    'source_group': 37,
#    'source_name': ' (Seroquel®)',
#    'target': 'E7',
#    'target_group': 37,
#    'target_name': ' quetiapine fumarate',
#    'value': 6},
#   {'id': 'R86',
#    'name': 'MODIFY',
#    'source': 'T13',
#    'source_group': 24,
#    'source_name': ' 900 mg daily',
#    'target': 'E7',
#    'target_group': 37,
#    'target_name': ' quetiapine fumarate',
#    'value': 4},
#   {'id': 'R87',
#    'name': 'MODIFY',
#    'source': 'T17',
#    'source_group': 24,
#    'source_name': ' 54 mg daily',
#    'target': 'E10',
#    'target_group': 37,
#    'target_name': ' methylphenidate',
#    'value': 4},
#   {'id': 'R88',
#    'name': 'MODIFY',
#    'source': 'T64',
#    'source_group': 16,
#    'source_name': ' 38.4 °C',
#    'target': 'E41',
#    'target_group': 38,
#    'target_name': ' temperature',
#    'value': 4},
#   {'id': 'R89',
#    'name': 'MODIFY',
#    'source': 'T180',
#    'source_group': 17,
#    'source_name': ' his home',
#    'target': 'E102',
#    'target_group': 22,
#    'target_name': ' discharged',
#    'value': 4},
#   {'id': 'R1',
#    'name': 'IDENTICAL',
#    'source': 'E5',
#    'source_group': 38,
#    'source_name': ' BMI',
#    'target': 'E4',
#    'target_group': 38,
#    'target_name': ' body mass index',
#    'value': 6},
#   {'id': 'R90',
#    'name': 'BEFORE',
#    'source': 'E4',
#    'source_group': 38,
#    'source_name': ' body mass index',
#    'target': 'E7',
#    'target_group': 37,
#    'target_name': ' quetiapine fumarate',
#    'value': 3},
#   {'id': 'R91',
#    'name': 'BEFORE',
#    'source': 'E9',
#    'source_group': 12,
#    'source_name': ' April 2005',
#    'target': 'E10',
#    'target_group': 37,
#    'target_name': ' methylphenidate',
#    'value': 3},
#   {'id': 'R92',
#    'name': 'BEFORE',
#    'source': 'E12',
#    'source_group': 12,
#    'source_name': ' September 2005',
#    'target': 'E13',
#    'target_group': 12,
#    'target_name': ' beginning of August 2006',
#    'value': 3},
#   {'id': 'R93',
#    'name': 'MODIFY',
#    'source': 'T22',
#    'source_group': 2,
#    'source_name': ' severe',
#    'target': 'E15',
#    'target_group': 11,
#    'target_name': ' dyspnoea',
#    'value': 4},
#   {'id': 'R94',
#    'name': 'BEFORE',
#    'source': 'E28',
#    'source_group': 11,
#    'source_name': ' enlarged heart',
#    'target': 'E29',
#    'target_group': 11,
#    'target_name': ' hemoptysis',
#    'value': 3},
#   {'id': 'R95',
#    'name': 'BEFORE',
#    'source': 'E31',
#    'source_group': 11,
#    'source_name': ' embolism',
#    'target': 'E32',
#    'target_group': 34,
#    'target_name': ' cardiogenic shock',
#    'value': 3},
#   {'id': 'R96',
#    'name': 'BEFORE',
#    'source': 'E33',
#    'source_group': 37,
#    'source_name': ' vasoactive drugs',
#    'target': 'E34',
#    'target_group': 11,
#    'target_name': ' oliguric',
#    'value': 3},
#   {'id': 'R97',
#    'name': 'BEFORE',
#    'source': 'E35',
#    'source_group': 38,
#    'source_name': ' liver enzymes',
#    'target': 'E36',
#    'target_group': 22,
#    'target_name': ' referred',
#    'value': 3},
#   {'id': 'R98',
#    'name': 'IDENTICAL',
#    'source': 'E48',
#    'source_group': 38,
#    'source_name': ' EF',
#    'target': 'E47',
#    'target_group': 38,
#    'target_name': ' ejection fraction',
#    'value': 6},
#   {'id': 'R99',
#    'name': 'BEFORE',
#    'source': 'E50',
#    'source_group': 11,
#    'source_name': ' mitral regurgitation',
#    'target': 'E51',
#    'target_group': 33,
#    'target_name': ' hemodialysis',
#    'value': 3},
#   {'id': 'R100',
#    'name': 'BEFORE',
#    'source': 'E51',
#    'source_group': 33,
#    'source_name': ' hemodialysis',
#    'target': 'E52',
#    'target_group': 38,
#    'target_name': ' liver function',
#    'value': 3},
#   {'id': 'R101',
#    'name': 'BEFORE',
#    'source': 'E54',
#    'source_group': 38,
#    'source_name': ' renal function',
#    'target': 'E56',
#    'target_group': 12,
#    'target_name': ' After three days',
#    'value': 3},
#   {'id': 'R102',
#    'name': 'BEFORE',
#    'source': 'E70',
#    'source_group': 38,
#    'source_name': ' amyloid deposition',
#    'target': 'E113',
#    'target_group': 12,
#    'target_name': ' After three days',
#    'value': 3},
#   {'id': 'R103',
#    'name': 'MODIFY',
#    'source': 'T115',
#    'source_group': 17,
#    'source_name': ' National Hospital (Rikshospitalet, Oslo)',
#    'target': 'E110',
#    'target_group': 22,
#    'target_name': ' transferred',
#    'value': 4},
#   {'id': 'R104',
#    'name': 'BEFORE',
#    'source': 'E75',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E73',
#    'target_group': 33,
#    'target_name': ' intraaortic balloon pump',
#    'value': 3},
#   {'id': 'R105',
#    'name': 'IDENTICAL',
#    'source': 'E74',
#    'source_group': 33,
#    'source_name': ' IABP',
#    'target': 'E73',
#    'target_group': 33,
#    'target_name': ' intraaortic balloon pump',
#    'value': 6},
#   {'id': 'R106',
#    'name': 'BEFORE',
#    'source': 'E78',
#    'source_group': 38,
#    'source_name': ' Coronary angiography',
#    'target': 'E79',
#    'target_group': 38,
#    'target_name': ' biopsy',
#    'value': 3},
#   {'id': 'R54',
#    'name': 'BEFORE',
#    'source': 'E89',
#    'source_group': 38,
#    'source_name': ' EF',
#    'target': 'E90',
#    'target_group': 11,
#    'target_name': ' behavioral problems',
#    'value': 3},
#   {'id': 'R107',
#    'name': 'BEFORE',
#    'source': 'E92',
#    'source_group': 33,
#    'source_name': ' heart transplant',
#    'target': 'E94',
#    'target_group': 1,
#    'target_name': ' IABP',
#    'value': 3},
#   {'id': 'R108',
#    'name': 'BEFORE',
#    'source': 'E95',
#    'source_group': 35,
#    'source_name': ' 26 days',
#    'target': 'E96',
#    'target_group': 35,
#    'target_name': ' after 28 days',
#    'value': 3},
#   {'id': 'R109',
#    'name': 'BEFORE',
#    'source': 'E101',
#    'source_group': 37,
#    'source_name': ' diuretics',
#    'target': 'E103',
#    'target_group': 35,
#    'target_name': ' two weeks',
#    'value': 3},
#   {'id': 'R110',
#    'name': 'BEFORE',
#    'source': 'E104',
#    'source_group': 38,
#    'source_name': ' clinical status',
#    'target': 'E102',
#    'target_group': 22,
#    'target_name': ' discharged',
#    'value': 3},
#   {'id': 'R111',
#    'name': 'BEFORE',
#    'source': 'E106',
#    'source_group': 38,
#    'source_name': ' EF',
#    'target': 'E107',
#    'target_group': 12,
#    'target_name': ' March 2007',
#    'value': 3},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E1',
#    'source_group': 34,
#    'source_name': ' attention-deficit hyperactivity disorder',
#    'target': 'E3',
#    'target_group': 12,
#    'target_name': ' 2005',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E1',
#    'source_group': 34,
#    'source_name': ' attention-deficit hyperactivity disorder',
#    'target': 'E6',
#    'target_group': 11,
#    'target_name': ' overweight',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E1',
#    'source_group': 34,
#    'source_name': ' attention-deficit hyperactivity disorder',
#    'target': 'E4',
#    'target_group': 38,
#    'target_name': ' body mass index',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E3',
#    'source_group': 12,
#    'source_name': ' 2005',
#    'target': 'E6',
#    'target_group': 11,
#    'target_name': ' overweight',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E3',
#    'source_group': 12,
#    'source_name': ' 2005',
#    'target': 'E4',
#    'target_group': 38,
#    'target_name': ' body mass index',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E6',
#    'source_group': 11,
#    'source_name': ' overweight',
#    'target': 'E4',
#    'target_group': 38,
#    'target_name': ' body mass index',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E7',
#    'source_group': 37,
#    'source_name': ' quetiapine fumarate',
#    'target': 'E9',
#    'target_group': 12,
#    'target_name': ' April 2005',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E10',
#    'source_group': 37,
#    'source_name': ' methylphenidate',
#    'target': 'E12',
#    'target_group': 12,
#    'target_name': ' September 2005',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E13',
#    'source_group': 12,
#    'source_name': ' beginning of August 2006',
#    'target': 'E14',
#    'target_group': 22,
#    'target_name': ' admitted',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E13',
#    'source_group': 12,
#    'source_name': ' beginning of August 2006',
#    'target': 'E15',
#    'target_group': 11,
#    'target_name': ' dyspnoea',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E13',
#    'source_group': 12,
#    'source_name': ' beginning of August 2006',
#    'target': 'E16',
#    'target_group': 11,
#    'target_name': ' tachypnea',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E13',
#    'source_group': 12,
#    'source_name': ' beginning of August 2006',
#    'target': 'E17',
#    'target_group': 11,
#    'target_name': ' tachycardia',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E13',
#    'source_group': 12,
#    'source_name': ' beginning of August 2006',
#    'target': 'E18',
#    'target_group': 11,
#    'target_name': ' cyanosis',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E13',
#    'source_group': 12,
#    'source_name': ' beginning of August 2006',
#    'target': 'E19',
#    'target_group': 22,
#    'target_name': ' admission',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E13',
#    'source_group': 12,
#    'source_name': ' beginning of August 2006',
#    'target': 'E20',
#    'target_group': 38,
#    'target_name': ' blood pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E13',
#    'source_group': 12,
#    'source_name': ' beginning of August 2006',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E13',
#    'source_group': 12,
#    'source_name': ' beginning of August 2006',
#    'target': 'E26',
#    'target_group': 38,
#    'target_name': ' C-reactive protein',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E13',
#    'source_group': 12,
#    'source_name': ' beginning of August 2006',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E13',
#    'source_group': 12,
#    'source_name': ' beginning of August 2006',
#    'target': 'E28',
#    'target_group': 11,
#    'target_name': ' enlarged heart',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E14',
#    'source_group': 22,
#    'source_name': ' admitted',
#    'target': 'E15',
#    'target_group': 11,
#    'target_name': ' dyspnoea',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E14',
#    'source_group': 22,
#    'source_name': ' admitted',
#    'target': 'E16',
#    'target_group': 11,
#    'target_name': ' tachypnea',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E14',
#    'source_group': 22,
#    'source_name': ' admitted',
#    'target': 'E17',
#    'target_group': 11,
#    'target_name': ' tachycardia',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E14',
#    'source_group': 22,
#    'source_name': ' admitted',
#    'target': 'E18',
#    'target_group': 11,
#    'target_name': ' cyanosis',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E14',
#    'source_group': 22,
#    'source_name': ' admitted',
#    'target': 'E19',
#    'target_group': 22,
#    'target_name': ' admission',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E14',
#    'source_group': 22,
#    'source_name': ' admitted',
#    'target': 'E20',
#    'target_group': 38,
#    'target_name': ' blood pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E14',
#    'source_group': 22,
#    'source_name': ' admitted',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E14',
#    'source_group': 22,
#    'source_name': ' admitted',
#    'target': 'E26',
#    'target_group': 38,
#    'target_name': ' C-reactive protein',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E14',
#    'source_group': 22,
#    'source_name': ' admitted',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E14',
#    'source_group': 22,
#    'source_name': ' admitted',
#    'target': 'E28',
#    'target_group': 11,
#    'target_name': ' enlarged heart',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E15',
#    'source_group': 11,
#    'source_name': ' dyspnoea',
#    'target': 'E16',
#    'target_group': 11,
#    'target_name': ' tachypnea',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E15',
#    'source_group': 11,
#    'source_name': ' dyspnoea',
#    'target': 'E17',
#    'target_group': 11,
#    'target_name': ' tachycardia',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E15',
#    'source_group': 11,
#    'source_name': ' dyspnoea',
#    'target': 'E18',
#    'target_group': 11,
#    'target_name': ' cyanosis',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E15',
#    'source_group': 11,
#    'source_name': ' dyspnoea',
#    'target': 'E19',
#    'target_group': 22,
#    'target_name': ' admission',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E15',
#    'source_group': 11,
#    'source_name': ' dyspnoea',
#    'target': 'E20',
#    'target_group': 38,
#    'target_name': ' blood pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E15',
#    'source_group': 11,
#    'source_name': ' dyspnoea',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E15',
#    'source_group': 11,
#    'source_name': ' dyspnoea',
#    'target': 'E26',
#    'target_group': 38,
#    'target_name': ' C-reactive protein',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E15',
#    'source_group': 11,
#    'source_name': ' dyspnoea',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E15',
#    'source_group': 11,
#    'source_name': ' dyspnoea',
#    'target': 'E28',
#    'target_group': 11,
#    'target_name': ' enlarged heart',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E16',
#    'source_group': 11,
#    'source_name': ' tachypnea',
#    'target': 'E17',
#    'target_group': 11,
#    'target_name': ' tachycardia',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E16',
#    'source_group': 11,
#    'source_name': ' tachypnea',
#    'target': 'E18',
#    'target_group': 11,
#    'target_name': ' cyanosis',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E16',
#    'source_group': 11,
#    'source_name': ' tachypnea',
#    'target': 'E19',
#    'target_group': 22,
#    'target_name': ' admission',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E16',
#    'source_group': 11,
#    'source_name': ' tachypnea',
#    'target': 'E20',
#    'target_group': 38,
#    'target_name': ' blood pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E16',
#    'source_group': 11,
#    'source_name': ' tachypnea',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E16',
#    'source_group': 11,
#    'source_name': ' tachypnea',
#    'target': 'E26',
#    'target_group': 38,
#    'target_name': ' C-reactive protein',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E16',
#    'source_group': 11,
#    'source_name': ' tachypnea',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E16',
#    'source_group': 11,
#    'source_name': ' tachypnea',
#    'target': 'E28',
#    'target_group': 11,
#    'target_name': ' enlarged heart',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E17',
#    'source_group': 11,
#    'source_name': ' tachycardia',
#    'target': 'E18',
#    'target_group': 11,
#    'target_name': ' cyanosis',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E17',
#    'source_group': 11,
#    'source_name': ' tachycardia',
#    'target': 'E19',
#    'target_group': 22,
#    'target_name': ' admission',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E17',
#    'source_group': 11,
#    'source_name': ' tachycardia',
#    'target': 'E20',
#    'target_group': 38,
#    'target_name': ' blood pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E17',
#    'source_group': 11,
#    'source_name': ' tachycardia',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E17',
#    'source_group': 11,
#    'source_name': ' tachycardia',
#    'target': 'E26',
#    'target_group': 38,
#    'target_name': ' C-reactive protein',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E17',
#    'source_group': 11,
#    'source_name': ' tachycardia',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E17',
#    'source_group': 11,
#    'source_name': ' tachycardia',
#    'target': 'E28',
#    'target_group': 11,
#    'target_name': ' enlarged heart',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E18',
#    'source_group': 11,
#    'source_name': ' cyanosis',
#    'target': 'E19',
#    'target_group': 22,
#    'target_name': ' admission',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E18',
#    'source_group': 11,
#    'source_name': ' cyanosis',
#    'target': 'E20',
#    'target_group': 38,
#    'target_name': ' blood pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E18',
#    'source_group': 11,
#    'source_name': ' cyanosis',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E18',
#    'source_group': 11,
#    'source_name': ' cyanosis',
#    'target': 'E26',
#    'target_group': 38,
#    'target_name': ' C-reactive protein',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E18',
#    'source_group': 11,
#    'source_name': ' cyanosis',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E18',
#    'source_group': 11,
#    'source_name': ' cyanosis',
#    'target': 'E28',
#    'target_group': 11,
#    'target_name': ' enlarged heart',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E19',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E20',
#    'target_group': 38,
#    'target_name': ' blood pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E19',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E19',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E26',
#    'target_group': 38,
#    'target_name': ' C-reactive protein',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E19',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E19',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E28',
#    'target_group': 11,
#    'target_name': ' enlarged heart',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E20',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E21',
#    'target_group': 38,
#    'target_name': ' arterial blood gas',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E20',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E26',
#    'target_group': 38,
#    'target_name': ' C-reactive protein',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E20',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E20',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E28',
#    'target_group': 11,
#    'target_name': ' enlarged heart',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E21',
#    'source_group': 38,
#    'source_name': ' arterial blood gas',
#    'target': 'E26',
#    'target_group': 38,
#    'target_name': ' C-reactive protein',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E21',
#    'source_group': 38,
#    'source_name': ' arterial blood gas',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E21',
#    'source_group': 38,
#    'source_name': ' arterial blood gas',
#    'target': 'E28',
#    'target_group': 11,
#    'target_name': ' enlarged heart',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E26',
#    'source_group': 38,
#    'source_name': ' C-reactive protein',
#    'target': 'E27',
#    'target_group': 38,
#    'target_name': ' X-ray',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E26',
#    'source_group': 38,
#    'source_name': ' C-reactive protein',
#    'target': 'E28',
#    'target_group': 11,
#    'target_name': ' enlarged heart',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E27',
#    'source_group': 38,
#    'source_name': ' X-ray',
#    'target': 'E28',
#    'target_group': 11,
#    'target_name': ' enlarged heart',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E29',
#    'source_group': 11,
#    'source_name': ' hemoptysis',
#    'target': 'E30',
#    'target_group': 37,
#    'target_name': ' heparin',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E29',
#    'source_group': 11,
#    'source_name': ' hemoptysis',
#    'target': 'E31',
#    'target_group': 11,
#    'target_name': ' embolism',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E30',
#    'source_group': 37,
#    'source_name': ' heparin',
#    'target': 'E31',
#    'target_group': 11,
#    'target_name': ' embolism',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E32',
#    'source_group': 34,
#    'source_name': ' cardiogenic shock',
#    'target': 'E33',
#    'target_group': 37,
#    'target_name': ' vasoactive drugs',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E34',
#    'source_group': 11,
#    'source_name': ' oliguric',
#    'target': 'E35',
#    'target_group': 38,
#    'target_name': ' liver enzymes',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E37',
#    'target_group': 22,
#    'target_name': ' admission',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E38',
#    'target_group': 38,
#    'target_name': ' blood pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E39',
#    'target_group': 37,
#    'target_name': ' noradrenaline',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E40',
#    'target_group': 38,
#    'target_name': ' heart rate',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E41',
#    'target_group': 38,
#    'target_name': ' temperature',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E42',
#    'target_group': 38,
#    'target_name': ' computed tomography scan',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E44',
#    'target_group': 38,
#    'target_name': ' Echocardiography',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E45',
#    'target_group': 11,
#    'target_name': ' biventricular failure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E46',
#    'target_group': 38,
#    'target_name': ' left ventricular end diastolic diameter',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E47',
#    'target_group': 38,
#    'target_name': ' ejection fraction',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E49',
#    'target_group': 38,
#    'target_name': ' left ventricular end diastolic pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E36',
#    'source_group': 22,
#    'source_name': ' referred',
#    'target': 'E50',
#    'target_group': 11,
#    'target_name': ' mitral regurgitation',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E37',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E38',
#    'target_group': 38,
#    'target_name': ' blood pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E37',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E39',
#    'target_group': 37,
#    'target_name': ' noradrenaline',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E37',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E40',
#    'target_group': 38,
#    'target_name': ' heart rate',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E37',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E41',
#    'target_group': 38,
#    'target_name': ' temperature',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E37',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E42',
#    'target_group': 38,
#    'target_name': ' computed tomography scan',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E37',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E44',
#    'target_group': 38,
#    'target_name': ' Echocardiography',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E37',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E45',
#    'target_group': 11,
#    'target_name': ' biventricular failure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E37',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E46',
#    'target_group': 38,
#    'target_name': ' left ventricular end diastolic diameter',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E37',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E47',
#    'target_group': 38,
#    'target_name': ' ejection fraction',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E37',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E49',
#    'target_group': 38,
#    'target_name': ' left ventricular end diastolic pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E37',
#    'source_group': 22,
#    'source_name': ' admission',
#    'target': 'E50',
#    'target_group': 11,
#    'target_name': ' mitral regurgitation',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E38',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E39',
#    'target_group': 37,
#    'target_name': ' noradrenaline',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E38',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E40',
#    'target_group': 38,
#    'target_name': ' heart rate',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E38',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E41',
#    'target_group': 38,
#    'target_name': ' temperature',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E38',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E42',
#    'target_group': 38,
#    'target_name': ' computed tomography scan',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E38',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E44',
#    'target_group': 38,
#    'target_name': ' Echocardiography',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E38',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E45',
#    'target_group': 11,
#    'target_name': ' biventricular failure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E38',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E46',
#    'target_group': 38,
#    'target_name': ' left ventricular end diastolic diameter',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E38',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E47',
#    'target_group': 38,
#    'target_name': ' ejection fraction',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E38',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E49',
#    'target_group': 38,
#    'target_name': ' left ventricular end diastolic pressure',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E38',
#    'source_group': 38,
#    'source_name': ' blood pressure',
#    'target': 'E50',
#    'target_group': 11,
#    'target_name': ' mitral regurgitation',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E39',
#    'source_group': 37,
#    'source_name': ' noradrenaline',
#    'target': 'E40',
#    'target_group': 38,
#    'target_name': ' heart rate',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E39',
#    'source_group': 37,
#    'source_name': ' noradrenaline',
#    'target': 'E41',
#    'target_group': 38,
#    'target_name': ' temperature',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E39',
#    'source_group': 37,
#    'source_name': ' noradrenaline',
#    'target': 'E42',
#    'target_group': 38,
#    'target_name': ' computed tomography scan',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E39',
#    'source_group': 37,
#    'source_name': ' noradrenaline',
#    'target': 'E44',
#    'target_group': 38,
#    'target_name': ' Echocardiography',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E39',
#    'source_group': 37,
#    'source_name': ' noradrenaline',
#    'target': 'E45',
#    'target_group': 11,
# ...
#    'target_name': ' function class',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E108',
#    'source_group': 38,
#    'source_name': ' clinical status',
#    'target': 'E111',
#    'target_group': 38,
#    'target_name': ' EF',
#    'value': 8},
#   {'id': 'ST',
#    'name': 'OVERLAP',
#    'source': 'E109',
#    'source_group': 38,
#    'source_name': ' function class',
#    'target': 'E111',
#    'target_group': 38,
#    'target_name': ' EF',
#    'value': 8}],
#  'nodes': [{'group': 10, 'id': 'T1', 'name': ' 18-year-old', 'type': 'Age'},
#   {'group': 6, 'id': 'T2', 'name': ' male', 'type': 'Gender'},
#   {'group': 16, 'id': 'T8', 'name': ' 40', 'type': 'Lab_value'},
#   {'group': 13, 'id': 'T9', 'name': ' overweight', 'type': 'History'},
#   {'group': 24, 'id': 'T13', 'name': ' 900 mg daily', 'type': 'Dosage'},
#   {'group': 24, 'id': 'T17', 'name': ' 54 mg daily', 'type': 'Dosage'},
#   {'group': 17,
#    'id': 'T21',
#    'name': ' local hospital',
#    'type': 'Nonbiological_location'},
#   {'group': 2, 'id': 'T22', 'name': ' severe', 'type': 'Severity'},
#   {'group': 16, 'id': 'T29', 'name': ' 120/80 mmHg', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T32', 'name': ' 7.45', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T36', 'name': ' 3.55 kPa', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T37', 'name': ' 7.76 kPa', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T38', 'name': ' −5.1 mmol/l', 'type': 'Lab_value'},
#   {'group': 28,
#    'id': 'T40',
#    'name': ' not elevated',
#    'type': 'Qualitative_concept'},
#   {'group': 7, 'id': 'T41', 'name': ' chest', 'type': 'Biological_structure'},
#   {'group': 27,
#    'id': 'T46',
#    'name': ' unfractionated',
#    'type': 'Detailed_description'},
#   {'group': 7,
#    'id': 'T47',
#    'name': ' pulmonary',
#    'type': 'Biological_structure'},
#   {'group': 28, 'id': 'T53', 'name': ' rising', 'type': 'Qualitative_concept'},
#   {'group': 17,
#    'id': 'T55',
#    'name': ' hospital',
#    'type': 'Nonbiological_location'},
#   {'group': 16, 'id': 'T58', 'name': ' 90/60 mmHg', 'type': 'Lab_value'},
#   {'group': 18, 'id': 'T60', 'name': ' infusion', 'type': 'Administration'},
#   {'group': 16, 'id': 'T62', 'name': ' 130/minute', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T64', 'name': ' 38.4 °C', 'type': 'Lab_value'},
#   {'group': 7,
#    'id': 'T66',
#    'name': ' thoracic',
#    'type': 'Biological_structure'},
#   {'group': 19, 'id': 'T70', 'name': ' 7 cm', 'type': 'Distance'},
#   {'group': 7,
#    'id': 'T72',
#    'name': ' left ventricle',
#    'type': 'Biological_structure'},
#   {'group': 28,
#    'id': 'T73',
#    'name': ' hypokinetic',
#    'type': 'Qualitative_concept'},
#   {'group': 2, 'id': 'T74', 'name': ' severely', 'type': 'Severity'},
#   {'group': 16, 'id': 'T77', 'name': ' 20%–25%', 'type': 'Lab_value'},
#   {'group': 28,
#    'id': 'T79',
#    'name': ' elevated',
#    'type': 'Qualitative_concept'},
#   {'group': 28,
#    'id': 'T81',
#    'name': ' moderate',
#    'type': 'Qualitative_concept'},
#   {'group': 27,
#    'id': 'T83',
#    'name': ' Intermittent',
#    'type': 'Detailed_description'},
#   {'group': 28,
#    'id': 'T87',
#    'name': ' deteriorated',
#    'type': 'Qualitative_concept'},
#   {'group': 28,
#    'id': 'T88',
#    'name': ' improved',
#    'type': 'Qualitative_concept'},
#   {'group': 2, 'id': 'T89', 'name': ' slightly', 'type': 'Severity'},
#   {'group': 28,
#    'id': 'T91',
#    'name': ' increasing',
#    'type': 'Qualitative_concept'},
#   {'group': 28,
#    'id': 'T94',
#    'name': ' worsening',
#    'type': 'Qualitative_concept'},
#   {'group': 16, 'id': 'T96', 'name': ' 10%–12%', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T99', 'name': ' 30 mmHg', 'type': 'Lab_value'},
#   {'group': 27,
#    'id': 'T101',
#    'name': ' dilated',
#    'type': 'Detailed_description'},
#   {'group': 7, 'id': 'T104', 'name': ' liver', 'type': 'Biological_structure'},
#   {'group': 7, 'id': 'T105', 'name': ' renal', 'type': 'Biological_structure'},
#   {'group': 27,
#    'id': 'T107',
#    'name': ' drug-induced',
#    'type': 'Detailed_description'},
#   {'group': 28,
#    'id': 'T114',
#    'name': ' negative',
#    'type': 'Qualitative_concept'},
#   {'group': 17,
#    'id': 'T115',
#    'name': ' National Hospital (Rikshospitalet, Oslo)',
#    'type': 'Nonbiological_location'},
#   {'group': 18, 'id': 'T118', 'name': ' infusions', 'type': 'Administration'},
#   {'group': 28,
#    'id': 'T125',
#    'name': ' normal',
#    'type': 'Qualitative_concept'},
#   {'group': 7,
#    'id': 'T127',
#    'name': ' Endomyocardial',
#    'type': 'Biological_structure'},
#   {'group': 7,
#    'id': 'T128',
#    'name': ' right ventricle',
#    'type': 'Biological_structure'},
#   {'group': 28,
#    'id': 'T134',
#    'name': ' normal',
#    'type': 'Qualitative_concept'},
#   {'group': 28,
#    'id': 'T136',
#    'name': ' improved',
#    'type': 'Qualitative_concept'},
#   {'group': 28,
#    'id': 'T138',
#    'name': ' improved',
#    'type': 'Qualitative_concept'},
#   {'group': 16, 'id': 'T141', 'name': ' 798', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T142', 'name': ' 98 μmol/l', 'type': 'Lab_value'},
#   {'group': 16, 'id': 'T144', 'name': ' 15%', 'type': 'Lab_value'},
#   {'group': 28,
#    'id': 'T145',
#    'name': ' reduced',
#    'type': 'Qualitative_concept'},
#   {'group': 17,
#    'id': 'T154',
#    'name': ' our hospital',
#    'type': 'Nonbiological_location'},
#   {'group': 28,
#    'id': 'T156',
#    'name': ' normal',
#    'type': 'Qualitative_concept'},
#   {'group': 28,
#    'id': 'T163',
#    'name': ' improved',
#    'type': 'Qualitative_concept'},
#   {'group': 16, 'id': 'T166', 'name': ' 20%', 'type': 'Lab_value'},
#   {'group': 7,
#    'id': 'T168',
#    'name': ' left ventricle',
#    'type': 'Biological_structure'},
#   {'group': 28,
#    'id': 'T169',
#    'name': ' dilated',
#    'type': 'Qualitative_concept'},
#   {'group': 28,
#    'id': 'T171',
#    'name': ' improved',
#    'type': 'Qualitative_concept'},
#   {'group': 28, 'id': 'T173', 'name': ' II', 'type': 'Qualitative_concept'},
#   {'group': 16, 'id': 'T177', 'name': ' 30%–35%', 'type': 'Lab_value'},
#   {'group': 27,
#    'id': 'T174',
#    'name': ' New York Heart Association',
#    'type': 'Detailed_description'},
#   {'group': 17,
#    'id': 'T180',
#    'name': ' his home',
#    'type': 'Nonbiological_location'},
#   {'group': 34,
#    'id': 'E1',
#    'name': ' attention-deficit hyperactivity disorder',
#    'type': 'Disease_disorder'},
#   {'group': 34, 'id': 'E2', 'name': ' ADHD', 'type': 'Disease_disorder'},
#   {'group': 12, 'id': 'E3', 'name': ' 2005', 'type': 'Date'},
#   {'group': 38,
#    'id': 'E4',
#    'name': ' body mass index',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E5', 'name': ' BMI', 'type': 'Diagnostic_procedure'},
#   {'group': 11, 'id': 'E6', 'name': ' overweight', 'type': 'Sign_symptom'},
#   {'group': 37,
#    'id': 'E7',
#    'name': ' quetiapine fumarate',
#    'type': 'Medication'},
#   {'group': 37, 'id': 'E8', 'name': ' (Seroquel®)', 'type': 'Medication'},
#   {'group': 12, 'id': 'E9', 'name': ' April 2005', 'type': 'Date'},
#   {'group': 37, 'id': 'E10', 'name': ' methylphenidate', 'type': 'Medication'},
#   {'group': 37, 'id': 'E11', 'name': ' (Concerta®)', 'type': 'Medication'},
#   {'group': 12, 'id': 'E12', 'name': ' September 2005', 'type': 'Date'},
#   {'group': 12,
#    'id': 'E13',
#    'name': ' beginning of August 2006',
#    'type': 'Date'},
#   {'group': 22, 'id': 'E14', 'name': ' admitted', 'type': 'Activity'},
#   {'group': 11, 'id': 'E15', 'name': ' dyspnoea', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E16', 'name': ' tachypnea', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E17', 'name': ' tachycardia', 'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E18', 'name': ' cyanosis', 'type': 'Sign_symptom'},
#   {'group': 22, 'id': 'E19', 'name': ' admission', 'type': 'Activity'},
#   {'group': 38,
#    'id': 'E20',
#    'name': ' blood pressure',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E21',
#    'name': ' arterial blood gas',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E22', 'name': ' pH', 'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E23', 'name': ' pCO2', 'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E24', 'name': ' paO2', 'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E25', 'name': ' BE', 'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E26',
#    'name': ' C-reactive protein',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E27', 'name': ' X-ray', 'type': 'Diagnostic_procedure'},
#   {'group': 11,
#    'id': 'E28',
#    'name': ' enlarged heart',
#    'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E29', 'name': ' hemoptysis', 'type': 'Sign_symptom'},
#   {'group': 37, 'id': 'E30', 'name': ' heparin', 'type': 'Medication'},
#   {'group': 11, 'id': 'E31', 'name': ' embolism', 'type': 'Sign_symptom'},
#   {'group': 34,
#    'id': 'E32',
#    'name': ' cardiogenic shock',
#    'type': 'Disease_disorder'},
#   {'group': 37,
#    'id': 'E33',
#    'name': ' vasoactive drugs',
#    'type': 'Medication'},
#   {'group': 11, 'id': 'E34', 'name': ' oliguric', 'type': 'Sign_symptom'},
#   {'group': 38,
#    'id': 'E35',
#    'name': ' liver enzymes',
#    'type': 'Diagnostic_procedure'},
#   {'group': 22, 'id': 'E36', 'name': ' referred', 'type': 'Activity'},
#   {'group': 22, 'id': 'E37', 'name': ' admission', 'type': 'Activity'},
#   {'group': 38,
#    'id': 'E38',
#    'name': ' blood pressure',
#    'type': 'Diagnostic_procedure'},
#   {'group': 37, 'id': 'E39', 'name': ' noradrenaline', 'type': 'Medication'},
#   {'group': 38,
#    'id': 'E40',
#    'name': ' heart rate',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E41',
#    'name': ' temperature',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E42',
#    'name': ' computed tomography scan',
#    'type': 'Diagnostic_procedure'},
#   {'group': 11,
#    'id': 'E43',
#    'name': ' did not show pulmonary embolism',
#    'type': 'Sign_symptom'},
#   {'group': 38,
#    'id': 'E44',
#    'name': ' Echocardiography',
#    'type': 'Diagnostic_procedure'},
#   {'group': 11,
#    'id': 'E45',
#    'name': ' biventricular failure',
#    'type': 'Sign_symptom'},
#   {'group': 38,
#    'id': 'E46',
#    'name': ' left ventricular end diastolic diameter',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E47',
#    'name': ' ejection fraction',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E48', 'name': ' EF', 'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E49',
#    'name': ' left ventricular end diastolic pressure',
#    'type': 'Diagnostic_procedure'},
#   {'group': 11,
#    'id': 'E50',
#    'name': ' mitral regurgitation',
#    'type': 'Sign_symptom'},
#   {'group': 33,
#    'id': 'E51',
#    'name': ' hemodialysis',
#    'type': 'Therapeutic_procedure'},
#   {'group': 38,
#    'id': 'E52',
#    'name': ' liver function',
#    'type': 'Diagnostic_procedure'},
#   {'group': 1, 'id': 'E53', 'name': ' dialysis', 'type': 'Coreference'},
#   {'group': 38,
#    'id': 'E54',
#    'name': ' renal function',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E55',
#    'name': ' creatinine values',
#    'type': 'Diagnostic_procedure'},
#   {'group': 12, 'id': 'E56', 'name': ' After three days', 'type': 'Date'},
#   {'group': 38,
#    'id': 'E57',
#    'name': ' left ventricular systolic function',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E58',
#    'name': ' ejection fraction',
#    'type': 'Diagnostic_procedure'},
#   {'group': 11,
#    'id': 'E59',
#    'name': ' pulmonary hypertension',
#    'type': 'Sign_symptom'},
#   {'group': 38,
#    'id': 'E60',
#    'name': ' systolic pulmonary pressure',
#    'type': 'Diagnostic_procedure'},
#   {'group': 34,
#    'id': 'E61',
#    'name': ' cardiomyopathy',
#    'type': 'Disease_disorder'},
#   {'group': 11,
#    'id': 'E62',
#    'name': ' low output failure',
#    'type': 'Sign_symptom'},
#   {'group': 11, 'id': 'E63', 'name': ' failure', 'type': 'Sign_symptom'},
#   {'group': 1, 'id': 'E64', 'name': ' cardiomyopathy', 'type': 'Coreference'},
#   {'group': 37, 'id': 'E65', 'name': ' methylphenidate', 'type': 'Medication'},
#   {'group': 37,
#    'id': 'E66',
#    'name': ' quetiapine fumarate',
#    'type': 'Medication'},
#   {'group': 38,
#    'id': 'E67',
#    'name': ' Screening for infectious pathogens',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E68',
#    'name': ' immunological markers',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E69', 'name': ' iron', 'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E70',
#    'name': ' amyloid deposition',
#    'type': 'Diagnostic_procedure'},
#   {'group': 37, 'id': 'E71', 'name': ' noradrenaline', 'type': 'Medication'},
#   {'group': 37, 'id': 'E72', 'name': ' dobutamine', 'type': 'Medication'},
#   {'group': 33,
#    'id': 'E73',
#    'name': ' intraaortic balloon pump',
#    'type': 'Therapeutic_procedure'},
#   {'group': 33, 'id': 'E74', 'name': ' IABP', 'type': 'Therapeutic_procedure'},
#   {'group': 22, 'id': 'E75', 'name': ' admission', 'type': 'Activity'},
#   {'group': 1, 'id': 'E76', 'name': ' noradrenaline', 'type': 'Coreference'},
#   {'group': 37, 'id': 'E77', 'name': ' nitroprusside', 'type': 'Medication'},
#   {'group': 38,
#    'id': 'E78',
#    'name': ' Coronary angiography',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E79',
#    'name': ' biopsy',
#    'type': 'Diagnostic_procedure'},
#   {'group': 34,
#    'id': 'E80',
#    'name': ' myocardial pathology',
#    'type': 'Disease_disorder'},
#   {'group': 1, 'id': 'E81', 'name': ' IABP', 'type': 'Coreference'},
#   {'group': 1, 'id': 'E82', 'name': ' nitroprusside', 'type': 'Coreference'},
#   {'group': 38,
#    'id': 'E84',
#    'name': ' liver function',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E85',
#    'name': ' clinical situation',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E86',
#    'name': ' renal function',
#    'type': 'Diagnostic_procedure'},
#   {'group': 11, 'id': 'E87', 'name': ' diuresis', 'type': 'Sign_symptom'},
#   {'group': 38,
#    'id': 'E88',
#    'name': ' creatinine',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E89', 'name': ' EF', 'type': 'Diagnostic_procedure'},
#   {'group': 11,
#    'id': 'E90',
#    'name': ' behavioral problems',
#    'type': 'Sign_symptom'},
#   {'group': 11,
#    'id': 'E91',
#    'name': ' adipose stature',
#    'type': 'Sign_symptom'},
#   {'group': 33,
#    'id': 'E92',
#    'name': ' heart transplant',
#    'type': 'Therapeutic_procedure'},
#   {'group': 22, 'id': 'E93', 'name': ' denied', 'type': 'Activity'},
#   {'group': 1, 'id': 'E94', 'name': ' IABP', 'type': 'Coreference'},
#   {'group': 35, 'id': 'E95', 'name': ' 26 days', 'type': 'Duration'},
#   {'group': 35, 'id': 'E96', 'name': ' after 28 days', 'type': 'Duration'},
#   {'group': 22, 'id': 'E97', 'name': ' transferred', 'type': 'Activity'},
#   {'group': 38,
#    'id': 'E98',
#    'name': ' liver and renal functions',
#    'type': 'Diagnostic_procedure'},
#   {'group': 37,
#    'id': 'E99',
#    'name': ' angiotensin-converting enzyme (ACE)-inhibitor',
#    'type': 'Medication'},
#   {'group': 37, 'id': 'E100', 'name': ' beta-blocker', 'type': 'Medication'},
#   {'group': 37, 'id': 'E101', 'name': ' diuretics', 'type': 'Medication'},
#   {'group': 22, 'id': 'E102', 'name': ' discharged', 'type': 'Activity'},
#   {'group': 35, 'id': 'E103', 'name': ' two weeks', 'type': 'Duration'},
#   {'group': 38,
#    'id': 'E104',
#    'name': ' clinical status',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E105',
#    'name': ' echocardiography',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E106', 'name': ' EF', 'type': 'Diagnostic_procedure'},
#   {'group': 12, 'id': 'E107', 'name': ' March 2007', 'type': 'Date'},
#   {'group': 38,
#    'id': 'E108',
#    'name': ' clinical status',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E109',
#    'name': ' function class',
#    'type': 'Diagnostic_procedure'},
#   {'group': 38, 'id': 'E111', 'name': ' EF', 'type': 'Diagnostic_procedure'},
#   {'group': 38,
#    'id': 'E112',
#    'name': ' echocardiography',
#    'type': 'Diagnostic_procedure'},
#   {'group': 22, 'id': 'E110', 'name': ' transferred', 'type': 'Activity'},
#   {'group': 12, 'id': 'E113', 'name': ' After three days', 'type': 'Date'},
#   {'group': 33,
#    'id': 'E83',
#    'name': ' dialysis',
#    'type': 'Therapeutic_procedure'}]}

# %%
import pandas as pd

# %%
Nodes = pd.DataFrame(DR.get_nodes(dump=True))

# %%
Nodes
# Out:
#      group    id                                            name  \
# 0       10    T1                                     18-year-old
# 1        6    T2                                            male
# 2       16    T8                                              40
# 3       13    T9                                      overweight
# 4       24   T13                                    900 mg daily
# 5       24   T17                                     54 mg daily
# 6       17   T21                                  local hospital
# 7        2   T22                                          severe
# 8       16   T29                                     120/80 mmHg
# 9       16   T32                                            7.45
# 10      16   T36                                        3.55 kPa
# 11      16   T37                                        7.76 kPa
# 12      16   T38                                     −5.1 mmol/l
# 13      28   T40                                    not elevated
# 14       7   T41                                           chest
# 15      27   T46                                  unfractionated
# 16       7   T47                                       pulmonary
# 17      28   T53                                          rising
# 18      17   T55                                        hospital
# 19      16   T58                                      90/60 mmHg
# 20      18   T60                                        infusion
# 21      16   T62                                      130/minute
# 22      16   T64                                         38.4 °C
# 23       7   T66                                        thoracic
# 24      19   T70                                            7 cm
# 25       7   T72                                  left ventricle
# 26      28   T73                                     hypokinetic
# 27       2   T74                                        severely
# 28      16   T77                                         20%–25%
# 29      28   T79                                        elevated
# ..     ...   ...                                             ...
# 510     38   E85                              clinical situation
# 511     38   E86                                  renal function
# 512     11   E87                                        diuresis
# 513     38   E88                                      creatinine
# 514     38   E89                                              EF
# 515     11   E90                             behavioral problems
# 516     11   E91                                 adipose stature
# 517     33   E92                                heart transplant
# 518     22   E93                                          denied
# 519      1   E94                                            IABP
# 520     35   E95                                         26 days
# 521     35   E96                                   after 28 days
# 522     22   E97                                     transferred
# 523     38   E98                       liver and renal functions
# 524     37   E99   angiotensin-converting enzyme (ACE)-inhibitor
# 525     37  E100                                    beta-blocker
# 526     37  E101                                       diuretics
# 527     22  E102                                      discharged
# 528     35  E103                                       two weeks
# 529     38  E104                                 clinical status
# 530     38  E105                                echocardiography
# 531     38  E106                                              EF
# 532     12  E107                                      March 2007
# 533     38  E108                                 clinical status
# 534     38  E109                                  function class
# 535     38  E111                                              EF
# 536     38  E112                                echocardiography
# 537     22  E110                                     transferred
# 538     12  E113                                After three days
# 539     33   E83                                        dialysis
#
#                        type
# 0                       Age
# 1                    Gender
# 2                 Lab_value
# 3                   History
# 4                    Dosage
# 5                    Dosage
# 6    Nonbiological_location
# 7                  Severity
# 8                 Lab_value
# 9                 Lab_value
# 10                Lab_value
# 11                Lab_value
# 12                Lab_value
# 13      Qualitative_concept
# 14     Biological_structure
# 15     Detailed_description
# 16     Biological_structure
# 17      Qualitative_concept
# 18   Nonbiological_location
# 19                Lab_value
# 20           Administration
# 21                Lab_value
# 22                Lab_value
# 23     Biological_structure
# 24                 Distance
# 25     Biological_structure
# 26      Qualitative_concept
# 27                 Severity
# 28                Lab_value
# 29      Qualitative_concept
# ..                      ...
# 510    Diagnostic_procedure
# 511    Diagnostic_procedure
# 512            Sign_symptom
# 513    Diagnostic_procedure
# 514    Diagnostic_procedure
# 515            Sign_symptom
# 516            Sign_symptom
# 517   Therapeutic_procedure
# 518                Activity
# 519             Coreference
# 520                Duration
# 521                Duration
# 522                Activity
# 523    Diagnostic_procedure
# 524              Medication
# 525              Medication
# 526              Medication
# 527                Activity
# 528                Duration
# 529    Diagnostic_procedure
# 530    Diagnostic_procedure
# 531    Diagnostic_procedure
# 532                    Date
# 533    Diagnostic_procedure
# 534    Diagnostic_procedure
# 535    Diagnostic_procedure
# 536    Diagnostic_procedure
# 537                Activity
# 538                    Date
# 539   Therapeutic_procedure
#
# [540 rows x 4 columns]

# %%
Edges = pd.DataFrame(DR.get_edges(dump =True))

# %%
Edges
# Out:
#        id           name source  source_group  \
# 0      R2         MODIFY     T8            16
# 1      R3         MODIFY    T32            16
# 2      R4         MODIFY    T36            16
# 3      R5         MODIFY    T37            16
# 4      R6         MODIFY    T38            16
# 5      R7  SUB_PROCEDURE    E22            38
# 6      R8  SUB_PROCEDURE    E23            38
# 7      R9  SUB_PROCEDURE    E24            38
# 8     R10  SUB_PROCEDURE    E25            38
# 9     R11         MODIFY    T40            28
# 10    R12         MODIFY    T41             7
# 11    R13         MODIFY    E28            11
# 12    R14         MODIFY    T46            27
# 13    R15         MODIFY    T47             7
# 14    R16         MODIFY    T53            28
# 15    R17         MODIFY    T60            18
# 16    R18         MODIFY    T66             7
# 17    R19         MODIFY    E43            11
# 18    R20         MODIFY    T70            19
# 19    R21         MODIFY    T73            28
# 20    R22         MODIFY    T74             2
# 21    R23         MODIFY    T79            28
# 22    R24         MODIFY    T81            28
# 23    R25         MODIFY    T83            27
# 24    R26      IDENTICAL    E53             1
# 25    R27         MODIFY    T87            28
# 26    R28         MODIFY    T88            28
# 27    R29         MODIFY    T89             2
# 28    R30  SUB_PROCEDURE    E55            38
# 29    R31         MODIFY    T91            28
# ...   ...            ...    ...           ...
# 1293   ST        OVERLAP    E90            11
# 1294   ST        OVERLAP    E91            11
# 1295   ST        OVERLAP    E91            11
# 1296   ST        OVERLAP    E93            22
# 1297   ST        OVERLAP    E94             1
# 1298   ST        OVERLAP    E96            35
# 1299   ST        OVERLAP    E96            35
# 1300   ST        OVERLAP    E96            35
# 1301   ST        OVERLAP    E96            35
# 1302   ST        OVERLAP    E96            35
# 1303   ST        OVERLAP    E97            22
# 1304   ST        OVERLAP    E97            22
# 1305   ST        OVERLAP    E97            22
# 1306   ST        OVERLAP    E97            22
# 1307   ST        OVERLAP    E98            38
# 1308   ST        OVERLAP    E98            38
# 1309   ST        OVERLAP    E98            38
# 1310   ST        OVERLAP    E99            37
# 1311   ST        OVERLAP    E99            37
# 1312   ST        OVERLAP   E100            37
# 1313   ST        OVERLAP   E103            35
# 1314   ST        OVERLAP   E102            22
# 1315   ST        OVERLAP   E102            22
# 1316   ST        OVERLAP   E105            38
# 1317   ST        OVERLAP   E107            12
# 1318   ST        OVERLAP   E107            12
# 1319   ST        OVERLAP   E107            12
# 1320   ST        OVERLAP   E108            38
# 1321   ST        OVERLAP   E108            38
# 1322   ST        OVERLAP   E109            38
#
#                                          source_name target  target_group  \
# 0                                                 40     E4            38
# 1                                               7.45    E22            38
# 2                                           3.55 kPa    E23            38
# 3                                           7.76 kPa    E24            38
# 4                                        −5.1 mmol/l    E25            38
# 5                                                 pH    E21            38
# 6                                               pCO2    E21            38
# 7                                               paO2    E21            38
# 8                                                 BE    E21            38
# 9                                       not elevated    E26            38
# 10                                             chest    E27            38
# 11                                    enlarged heart    E27            38
# 12                                    unfractionated    E30            37
# 13                                         pulmonary    E31            11
# 14                                            rising    E35            38
# 15                                          infusion    E39            37
# 16                                          thoracic    E42            38
# 17                   did not show pulmonary embolism    E42            38
# 18                                              7 cm    E46            38
# 19                                       hypokinetic    T72             7
# 20                                          severely    T73            28
# 21                                          elevated    E49            38
# 22                                          moderate    E50            11
# 23                                      Intermittent    E51            33
# 24                                          dialysis    E51            33
# 25                                      deteriorated    E54            38
# 26                                          improved    E52            38
# 27                                          slightly    T88            28
# 28                                 creatinine values    E54            38
# 29                                        increasing    E55            38
# ...                                              ...    ...           ...
# 1293                             behavioral problems    E92            33
# 1294                                 adipose stature    E93            22
# 1295                                 adipose stature    E92            33
# 1296                                          denied    E92            33
# 1297                                            IABP    E95            35
# 1298                                   after 28 days    E97            22
# 1299                                   after 28 days    E98            38
# 1300                                   after 28 days    E99            37
# 1301                                   after 28 days   E100            37
# 1302                                   after 28 days   E101            37
# 1303                                     transferred    E98            38
# 1304                                     transferred    E99            37
# 1305                                     transferred   E100            37
# 1306                                     transferred   E101            37
# 1307                       liver and renal functions    E99            37
# 1308                       liver and renal functions   E100            37
# 1309                       liver and renal functions   E101            37
# 1310   angiotensin-converting enzyme (ACE)-inhibitor   E100            37
# 1311   angiotensin-converting enzyme (ACE)-inhibitor   E101            37
# 1312                                    beta-blocker   E101            37
# 1313                                       two weeks   E104            38
# 1314                                      discharged   E105            38
# 1315                                      discharged   E106            38
# 1316                                echocardiography   E106            38
# 1317                                      March 2007   E108            38
# 1318                                      March 2007   E109            38
# 1319                                      March 2007   E111            38
# 1320                                 clinical status   E109            38
# 1321                                 clinical status   E111            38
# 1322                                  function class   E111            38
#
#                                          target_name  value
# 0                                    body mass index      4
# 1                                                 pH      4
# 2                                               pCO2      4
# 3                                               paO2      4
# 4                                                 BE      4
# 5                                 arterial blood gas      5
# 6                                 arterial blood gas      5
# 7                                 arterial blood gas      5
# 8                                 arterial blood gas      5
# 9                                 C-reactive protein      4
# 10                                             X-ray      4
# 11                                             X-ray      4
# 12                                           heparin      4
# 13                                          embolism      4
# 14                                     liver enzymes      4
# 15                                     noradrenaline      4
# 16                          computed tomography scan      4
# 17                          computed tomography scan      4
# 18           left ventricular end diastolic diameter      4
# 19                                    left ventricle      4
# 20                                       hypokinetic      4
# 21           left ventricular end diastolic pressure      4
# 22                              mitral regurgitation      4
# 23                                      hemodialysis      4
# 24                                      hemodialysis      6
# 25                                    renal function      4
# 26                                    liver function      4
# 27                                          improved      4
# 28                                    renal function      5
# 29                                 creatinine values      4
# ...                                              ...    ...
# 1293                                heart transplant      8
# 1294                                          denied      8
# 1295                                heart transplant      8
# 1296                                heart transplant      8
# 1297                                         26 days      8
# 1298                                     transferred      8
# 1299                       liver and renal functions      8
# 1300   angiotensin-converting enzyme (ACE)-inhibitor      8
# 1301                                    beta-blocker      8
# 1302                                       diuretics      8
# 1303                       liver and renal functions      8
# 1304   angiotensin-converting enzyme (ACE)-inhibitor      8
# 1305                                    beta-blocker      8
# 1306                                       diuretics      8
# 1307   angiotensin-converting enzyme (ACE)-inhibitor      8
# 1308                                    beta-blocker      8
# 1309                                       diuretics      8
# 1310                                    beta-blocker      8
# 1311                                       diuretics      8
# 1312                                       diuretics      8
# 1313                                 clinical status      8
# 1314                                echocardiography      8
# 1315                                              EF      8
# 1316                                              EF      8
# 1317                                 clinical status      8
# 1318                                  function class      8
# 1319                                              EF      8
# 1320                                  function class      8
# 1321                                              EF      8
# 1322                                              EF      8
#
# [1323 rows x 9 columns]
